# %% [markdown]
# # Assignment Group 1
# Name: Akhilesh Yadav Gaddam
#
# ## Module A _(25 points)_
#
# __A1.__ _(3 points)_ In this module, you will be working with the [Seinfeld Chronicles dataset](https://www.kaggle.com/thec03u5/seinfeld-chronicles). Create an account on [Kaggle](https://www.kaggle.com) and download the `scripts.csv` file from the dataset and move it into the `data` directory. Read the `data/scripts.csv` file as a text file line-by-line and examine the list you have loaded the data into.

# %%
lineList = []
with open("data/scripts.csv", "r") as file_handle:
    for line in file_handle:
        lineList.append(line.split('\n'))
    
for num in range(5):
    print(lineList[num])
# Out:
# [',Character,Dialogue,EpisodeNo,SEID,Season', '']
# ['0,JERRY,"Do you know what this is all about? Do you know, why were here? To be out, this is out...and out is one of the single most enjoyable experiences of life. People...did you ever hear people talking about We should go out? This is what theyre talking about...this whole thing, were all out now, no one is home. Not one person here is home, were all out! There are people tryin to find us, they dont know where we are. (on an imaginary phone) Did you ring?, I cant find him. Where did he go? He didnt tell me where he was going. He must have gone out. You wanna go out you get ready, you pick out the clothes, right? You take the shower, you get all ready, get the cash, get your friends, the car, the spot, the reservation...Then youre standing around, whatta you do? You go We gotta be getting back. Once youre out, you wanna get back! You wanna go to sleep, you wanna get up, you wanna go out again tomorrow, right? Where ever you are in life, its my feeling, youve gotta go.",1.0,S01E01,1.0', '']
# ['1,JERRY,"(pointing at Georges shirt) See, to me, that button is in the worst possible spot. The second button literally makes or breaks the shirt, look at it. Its too high! Its in no-mans-land. You look like you live with your mother.",1.0,S01E01,1.0', '']
# ['2,GEORGE,Are you through?,1.0,S01E01,1.0', '']
# ['3,JERRY,"You do of course try on, when you buy?",1.0,S01E01,1.0', '']

# %% [markdown]
# __A2.__ _(2 points)_ Is it possible to work with this data, simply splitting by a delimiter? Explain any complexity in the data's structured format that necessitates an established format-specific file reader.

# %% [markdown]
# ANS: No, we tried to process the data with both the delimiters (\n, ','). When we use the delimiter '\n' then too we have to process the data again with delimiter ',' and viceversa reason being the data file is in csv format. We have to use csv file reader in order to read the data in a structured format.

# %% [markdown]
# __A3.__ _(5 points)_ Use the `csv` module to read the contents of the `data/scripts.csv` file into a list. Examine this list. How many unique speaking characters are present in the scripts in total?
#
# __Important__: please don't get stuck on cleaning text in this module! It's great to take note of issues in data and even address them, but the regular expressions (regex) required to get heavily into that work is ahead in __Chapter 4__ and so not required here. Please just count characters and words as best possible using the topics from Chapters 0&ndash;2 (naïvely, even), and utilize the markdown response boxes to discuss what you see as being the challenges in working with these data and what solutions might be.

# %%
import csv
index = []
characters = []
dialouges = []
episodeNumber = []
seid = []
seasons = []
csvObject = csv.reader(open('data/scripts.csv', 'r'), delimiter=',')
count = 0
for line in csvObject:
    for idx, unit in enumerate(line):
        if count>0:
            if idx == 0:
                index.append(unit)
            elif idx == 1:
                characters.append(unit)
            elif idx == 2:
                dialouges.append(unit)
            elif idx == 3:
                episodeNumber.append(unit)
            elif idx == 4:
                seid.append(unit)
            elif idx == 5:
                seasons.append(unit)
    count += 1

df = {'index':index, 'character':characters, 'dialouge':dialouges, 'episodeNumber':episodeNumber, 'SeasonID': seid, 'season':seasons}

uniqueCharacters = []

for character in characters:
    if character not in uniqueCharacters:
        uniqueCharacters.append(character)

print('Number of unique speaking characters:', len(uniqueCharacters))
# Out:
# Number of unique speaking characters: 1639

# %% [markdown]
# __A4.__ _(2 points)_ Count the dialogue entries for the four major characters, "JERRY", "GEORGE", "ELAINE", and "KRAMER", using a dictionary (you are not allowed to use the Counter data structure for any component of this module).

# %%
mainCharacters = {"JERRY":0, "GEORGE":0, "ELAINE":0, "KRAMER":0}

for character in characters:
    if character in mainCharacters.keys():
        mainCharacters[character] +=1

mainCharacters
# Out:
# {'JERRY': 14786, 'GEORGE': 9708, 'ELAINE': 7983, 'KRAMER': 6664}

# %% [markdown]
# __A5.__ _(3 points)_ Count the number of words spoken by each of the main characters using a dictionary.

# %%
def dialougeToWord(dialouge):
    temp = list(dialouge.split(' '))
    return len(temp)

mainCharacters = {"JERRY":0, "GEORGE":0, "ELAINE":0, "KRAMER":0}


for idx,dialouge in enumerate(dialouges):
    if characters[idx] in mainCharacters.keys():
        mainCharacters[characters[idx]] += dialougeToWord(dialouge)


mainCharacters
# Out:
# {'JERRY': 147430, 'GEORGE': 107049, 'ELAINE': 74642, 'KRAMER': 70304}

# %% [markdown]
# __A6.__ _(5 points)_ Count how many times each word is spoken by the main characters using a dictionary, then sort these word counts in descending order, i.e. from the most commonly spoken words to least. [__Hint__: You can use either a lambda function or a list comprehension to do this.]

# %%
wordsDict = {'JERRY': [], 'GEORGE':[], 'ELAINE': [], 'KRAMER': []}
[[[wordsDict[characters[index]].append(word) for word in dialouge.split(' ')] for index, dialouge in enumerate(dialouges) if characters[index] == character] for character in wordsDict.keys()]


wordCounter = {'JERRY': {}, 'GEORGE':{}, 'ELAINE': {}, 'KRAMER': {}}
for character in mainCharacters.keys():
    for word in wordsDict[character]:
        if word not in wordCounter[character]:
            wordCounter[character][word] = 1
        else:
            wordCounter[character][word] += 1
            


import operator
for character in wordCounter.keys():
    wordCounter[character] = sorted(wordCounter[character].items(),key =operator.itemgetter(1) , reverse = True)
    
wordCounter
# Out:
# {'JERRY': [('the', 4708),
#   ('I', 4665),
#   ('you', 3622),
#   ('a', 3294),
#   ('to', 3059),
#   ('of', 1518),
#   ('in', 1304),
#   ('and', 1282),
#   ('You', 1188),
#   ('is', 1181),
#   ('that', 1150),
#   ('it', 1060),
#   ('with', 927),
#   ('on', 904),
#   ("I'm", 884),
#   ("don't", 832),
#   ('have', 803),
#   ('What', 799),
#   ('this', 794),
#   ('was', 793),
#   ('my', 772),
#   ('like', 751),
#   ('do', 749),
#   ('for', 746),
#   ('just', 704),
#   ('know', 693),
#   ('what', 682),
#   ('get', 682),
#   ('not', 672),
#   ('your', 620),
#   ('be', 619),
#   ('me', 596),
#   ('Oh,', 586),
#   ('are', 583),
#   ('about', 571),
#   ('at', 565),
#   ('he', 560),
#   ('Well,', 557),
#   ('out', 554),
#   ('it.', 517),
#   ('got', 502),
#   ('think', 473),
#   ('we', 461),
#   ('his', 451),
#   ('up', 451),
#   ('Yeah,', 450),
#   ("it's", 445),
#   ('So', 426),
#   ('all', 412),
#   ('they', 410),
#   ("It's", 408),
#   ('if', 407),
#   ('want', 395),
#   ('go', 389),
#   ('her', 376),
#   ('gonna', 375),
#   ('see', 374),
#   ('going', 358),
#   ('she', 350),
#   ('No,', 348),
#   ("you're", 344),
#   ('The', 331),
#   ('can', 324),
#   ('did', 313),
#   ('know,', 311),
#   ('Hey,', 308),
#   ("can't", 302),
#   ('an', 297),
#   ('How', 290),
#   ("That's", 288),
#   ('so', 287),
#   ('one', 285),
#   ('no', 280),
#   ("I'll", 274),
#   ('from', 272),
#   ('He', 271),
#   ('him', 268),
#   ('really', 262),
#   ('Oh', 255),
#   ("that's", 255),
#   ('but', 254),
#   ('would', 253),
#   ('had', 250),
#   ('All', 250),
#   ('you.', 249),
#   ('little', 249),
#   ('And', 248),
#   ('Yeah.', 247),
#   ('could', 244),
#   ('how', 242),
#   ('tell', 232),
#   ('some', 231),
#   ('me.', 229),
#   ("You're", 228),
#   ('Well', 222),
#   ("didn't", 222),
#   ("he's", 219),
#   ('over', 217),
#   ('it?', 212),
#   ('were', 211),
#   ('Why', 211),
#   ('come', 209),
#   ('take', 203),
#   ('back', 203),
#   ('good', 201),
#   ('-', 200),
#   ('It', 198),
#   ('right', 198),
#   ('there', 198),
#   ('never', 197),
#   ('What?', 194),
#   ('But', 194),
#   ('as', 189),
#   ('No', 186),
#   ('when', 183),
#   ('make', 179),
#   ('So,', 178),
#   ('been', 176),
#   ('very', 173),
#   ('you?', 172),
#   ('gotta', 168),
#   ('This', 166),
#   ('Im', 166),
#   ('then', 166),
#   ('down', 166),
#   ('She', 166),
#   ('thing', 164),
#   ('(to', 164),
#   ('George', 163),
#   ('that.', 163),
#   ('that?', 161),
#   ('dont', 160),
#   ('even', 159),
#   ('right.', 158),
#   ('know.', 158),
#   ('should', 157),
#   ("What's", 157),
#   ('say', 155),
#   ('They', 155),
#   ('here.', 151),
#   ('into', 146),
#   ('We', 144),
#   ('No.', 144),
#   ("He's", 142),
#   ('call', 140),
#   ('there.', 140),
#   ('guy', 140),
#   ('because', 140),
#   ('need', 138),
#   ('whole', 137),
#   ('any', 136),
#   ('off', 134),
#   ('here', 133),
#   ('told', 133),
#   ('something', 133),
#   ('Is', 133),
#   ('That', 133),
#   ('right,', 133),
#   ('put', 133),
#   ('doing', 133),
#   ('people', 132),
#   ('Come', 132),
#   ('said', 131),
#   ('you,', 130),
#   ('believe', 130),
#   ('other', 130),
#   ('up.', 130),
#   ('who', 129),
#   ('two', 128),
#   ('give', 127),
#   ("I've", 127),
#   ('why', 126),
#   ('by', 126),
#   ('Kramer,', 126),
#   ('where', 124),
#   ('look', 124),
#   ('thought', 122),
#   ('these', 122),
#   ('Elaine', 122),
#   ('uh,', 121),
#   ('this.', 121),
#   ('.', 120),
#   ('ever', 119),
#   ('getting', 118),
#   ('mean', 118),
#   ("she's", 118),
#   ('or', 117),
#   ('big', 116),
#   ('them', 115),
#   ('this?', 115),
#   ('talk', 114),
#   ('him.', 113),
#   ('wanna', 113),
#   ('Hey.', 112),
#   ('its', 111),
#   ('mean,', 111),
#   ('time', 111),
#   ('Did', 110),
#   ('those', 110),
#   ('what?', 110),
#   ('A', 110),
#   ("there's", 108),
#   ('way', 107),
#   ('Alright,', 107),
#   ('Kramer', 107),
#   ("they're", 107),
#   ('has', 106),
#   ("doesn't", 106),
#   ('kind', 105),
#   ('Hey', 105),
#   ('more', 104),
#   ('out.', 102),
#   ('Elaine,', 102),
#   ('Jerry', 102),
#   ('it,', 101),
#   ('always', 101),
#   ('still', 101),
#   ('Maybe', 100),
#   ('on.', 100),
#   ('me,', 99),
#   ('too', 98),
#   ('am', 98),
#   ('George,', 98),
#   ('much', 97),
#   ('If', 97),
#   ('anything', 96),
#   ('only', 94),
#   ("There's", 93),
#   ('talking', 91),
#   ('Where', 91),
#   ('do?', 91),
#   ('Just', 91),
#   ('around', 91),
#   ('sure', 91),
#   ("She's", 91),
#   ('here?', 90),
#   ('her.', 90),
#   ('maybe', 89),
#   ('let', 89),
#   ('Are', 89),
#   ('Ah,', 88),
#   ('...', 88),
#   ("what's", 87),
#   ('Do', 86),
#   ('go.', 86),
#   ('Not', 85),
#   ('Uh,', 85),
#   ('Who', 85),
#   ("we're", 85),
#   ('their', 84),
#   ('ask', 83),
#   ('now', 83),
#   ('last', 83),
#   ('no,', 82),
#   ('does', 81),
#   ('will', 81),
#   ('My', 81),
#   ('another', 81),
#   ('good.', 80),
#   ('bad', 80),
#   ('there?', 80),
#   ('Yes,', 79),
#   ('back.', 78),
#   ('show', 78),
#   ('love', 78),
#   ('than', 78),
#   ('woman', 77),
#   ('Really?', 77),
#   ('George)', 77),
#   ('it!', 77),
#   ('feel', 77),
#   ('time.', 77),
#   ("I'd", 77),
#   ('now.', 76),
#   ('Because', 76),
#   ('guess', 76),
#   ('better', 76),
#   ('Why?', 75),
#   ("Don't", 75),
#   ("They're", 75),
#   ('phone)', 74),
#   ('hear', 73),
#   ('(To', 73),
#   ('new', 72),
#   ('find', 70),
#   ('happened', 70),
#   ('George.', 70),
#   ('someone', 70),
#   ('Okay,', 69),
#   ('us', 69),
#   ('doing?', 68),
#   ('Now', 68),
#   ('trying', 68),
#   ('Look', 68),
#   ('being', 68),
#   ('me?', 67),
#   ('Its', 66),
#   ('went', 66),
#   ('(Jerry', 66),
#   ('lot', 66),
#   ('supposed', 66),
#   ('Hello?', 66),
#   ('youre', 65),
#   ('first', 65),
#   ('long', 65),
#   ('something.', 65),
#   ('coming', 64),
#   ('Kramer)', 64),
#   ("We're", 64),
#   ('wait', 63),
#   ('seen', 62),
#   ('do.', 62),
#   ('next', 62),
#   ('after', 62),
#   ('three', 62),
#   ('on,', 61),
#   ('Can', 61),
#   ('sorry.', 61),
#   ('looks', 61),
#   ('cant', 60),
#   ('meet', 60),
#   ('yeah,', 60),
#   ('is.', 60),
#   ('having', 60),
#   ('In', 60),
#   ("isn't", 60),
#   ('guy.', 59),
#   ('thing.', 59),
#   ('keep', 59),
#   ('nice', 59),
#   ('for?', 59),
#   ('pretty', 58),
#   ('made', 57),
#   ('saw', 57),
#   ('Elaine)', 57),
#   ('gave', 57),
#   ('might', 56),
#   ('in.', 56),
#   ('wanted', 56),
#   ('stop', 56),
#   ('again.', 56),
#   ('heard', 55),
#   ('yeah.', 55),
#   ('taking', 55),
#   ('hell', 55),
#   ('here,', 54),
#   ('nothing', 54),
#   ('well', 54),
#   ('door', 54),
#   ('friend', 54),
#   ('night.', 54),
#   ('Wait', 54),
#   ('looking', 54),
#   ('same', 54),
#   ('Oh.', 54),
#   ('Look,', 53),
#   ('Ill', 53),
#   ('comes', 53),
#   ('no.', 53),
#   ('Elaine.', 53),
#   ('Get', 53),
#   ('up,', 52),
#   ('goes', 52),
#   ('making', 52),
#   ('him?', 52),
#   ('care', 52),
#   ("wouldn't", 52),
#   ("let's", 52),
#   ("couldn't", 52),
#   ('Let', 51),
#   ('things', 51),
#   ('them.', 51),
#   ('great', 51),
#   ('our', 51),
#   ('happened?', 51),
#   ('car', 51),
#   ('pick', 50),
#   ('wrong', 50),
#   ('second.', 50),
#   ('through', 50),
#   ('well,', 50),
#   ('(George', 50),
#   ('(Kramer', 50),
#   ('There', 49),
#   ('wants', 49),
#   ('work', 49),
#   ('walk', 49),
#   ('Kramer.', 49),
#   ('about?', 48),
#   ('real', 48),
#   ('up)', 48),
#   ('Yeah', 48),
#   ('Thank', 48),
#   ('When', 48),
#   ('TV', 48),
#   ('phone', 48),
#   ('eat', 48),
#   ('called', 47),
#   ('came', 47),
#   ('remember', 47),
#   ('old', 47),
#   ('didnt', 46),
#   ('must', 46),
#   ('right?', 46),
#   ('that,', 46),
#   ('use', 46),
#   ('Hi.', 46),
#   ('before', 46),
#   ('sit', 46),
#   ('coffee', 46),
#   (',', 46),
#   ('gets', 45),
#   ('car.', 45),
#   ('Then', 45),
#   ('Boy,', 45),
#   ('try', 44),
#   ('Have', 44),
#   ('move', 44),
#   ('man', 44),
#   ('probably', 44),
#   ('anything.', 44),
#   ('help', 44),
#   ('Hi', 44),
#   ('ya', 44),
#   ("we'll", 44),
#   ('person', 43),
#   ('makes', 43),
#   ('day', 43),
#   ('Mr.', 43),
#   ('idea', 43),
#   ('one.', 43),
#   ('(Elaine', 43),
#   ('wear', 43),
#   ('life', 42),
#   ('head', 42),
#   ('thats', 42),
#   ('Thats', 42),
#   ('uh', 42),
#   ('every', 42),
#   ('', 41),
#   ('left', 41),
#   ('now?', 41),
#   ('Yes.', 41),
#   ("you've", 41),
#   ('life.', 40),
#   ('her?', 40),
#   ('leave', 40),
#   ('there,', 40),
#   ('Okay.', 40),
#   ("Let's", 40),
#   ("Kramer's", 40),
#   ('Alright.', 40),
#   ('What,', 39),
#   ('took', 39),
#   ('hand', 39),
#   ('Hi,', 39),
#   ('guys', 39),
#   ('Hey!', 39),
#   ('quite', 39),
#   ('each', 39),
#   ('apartment', 39),
#   ('fine.', 39),
#   ('actually', 39),
#   ('Hello.', 39),
#   ('this,', 39),
#   ('down.', 39),
#   ('kinda', 38),
#   ('I,', 38),
#   ('may', 38),
#   ('sorry', 38),
#   ('Uncle', 38),
#   ('off.', 38),
#   ('bad.', 38),
#   ('saying', 38),
#   ('telling', 38),
#   ('Youre', 37),
#   ('date', 37),
#   ('many', 37),
#   ('know?', 37),
#   ('Would', 37),
#   ('thank', 37),
#   ('Excuse', 37),
#   ('Good', 37),
#   ('years', 37),
#   ("you'll", 37),
#   ('out,', 36),
#   ('course', 36),
#   ('women', 36),
#   ('hold', 36),
#   ('men', 36),
#   ('front', 36),
#   ('pay', 36),
#   ('Of', 36),
#   ('else', 36),
#   ("'em", 36),
#   ('night', 35),
#   ('hate', 35),
#   ('waiting', 35),
#   ('Yeah?', 35),
#   ('bye.', 35),
#   ('end', 35),
#   ('idea.', 35),
#   ('away', 35),
#   ('able', 35),
#   ('go,', 35),
#   ('room', 35),
#   ('used', 35),
#   ('(he', 35),
#   ('now,', 34),
#   ('live', 34),
#   ('behind', 34),
#   ('calling', 34),
#   ('own', 34),
#   ('later.', 34),
#   ('money.', 34),
#   ('too.', 34),
#   ('minutes.', 34),
#   ("won't", 34),
#   ('going?', 34),
#   ("We'll", 34),
#   ('knew', 33),
#   ('door)', 33),
#   ('takes', 33),
#   ('Now,', 33),
#   ('not.', 33),
#   ('is,', 33),
#   ('money', 33),
#   ('Yes', 33),
#   ('Could', 33),
#   ('mean?', 33),
#   ('start', 33),
#   ("wasn't", 33),
#   ('Newman.', 33),
#   ('knows', 32),
#   ('parents', 32),
#   ('bring', 32),
#   ('wearing', 32),
#   ('Your', 32),
#   ('thinking', 32),
#   ('least', 32),
#   ('did.', 32),
#   ('buy', 32),
#   ('say?', 32),
#   ('asked', 32),
#   ("goin'", 32),
#   ('Oh!', 32),
#   ('most', 31),
#   ('theyre', 31),
#   ('met', 31),
#   ('Like', 31),
#   ('open', 31),
#   ('so.', 31),
#   ('like,', 31),
#   ('working', 31),
#   ('home', 31),
#   ('such', 31),
#   ('hit', 31),
#   ('play', 31),
#   ('piece', 31),
#   ('check', 31),
#   ('Go', 31),
#   ('place', 31),
#   ('Take', 31),
#   ('five', 31),
#   ("You've", 31),
#   ("haven't", 31),
#   ('up?', 31),
#   ('To', 30),
#   ('hes', 30),
#   ('watch', 30),
#   ('forget', 30),
#   ('mind', 30),
#   ('Hello,', 30),
#   ('sitting', 30),
#   ('New', 30),
#   ('almost', 29),
#   ('thinks', 29),
#   ('both', 29),
#   ('while', 29),
#   ('hundred', 29),
#   ('outta', 29),
#   ('hi', 29),
#   ('understand', 29),
#   ('out?', 28),
#   ('Yeah!', 28),
#   ('place.', 28),
#   ('half', 28),
#   ('somebody', 28),
#   ('few', 28),
#   ('him,', 28),
#   ('starts', 28),
#   ('room.', 28),
#   ('everything', 28),
#   ('that!', 28),
#   ('once', 27),
#   ('against', 27),
#   ('stay', 27),
#   ('okay.', 27),
#   ('dating', 27),
#   ('second,', 27),
#   ('say,', 27),
#   ('point', 27),
#   ('four', 27),
#   ('much.', 27),
#   ('hands', 27),
#   ('nothing.', 27),
#   ('--', 27),
#   ("you'd", 27),
#   ('not?', 27),
#   ('are.', 26),
#   ('great.', 26),
#   ('problem', 26),
#   ('father', 26),
#   ('Ive', 26),
#   ('tonight.', 26),
#   ('Seinfeld.', 26),
#   ('So?', 26),
#   ('read', 26),
#   ('anymore.', 26),
#   ('(They', 26),
#   ('found', 26),
#   ('name', 26),
#   ('under', 26),
#   ('boy.', 26),
#   ('Elaine?', 26),
#   ('funny', 26),
#   ('part', 26),
#   ('me!', 26),
#   ('Kramer!', 26),
#   ('Nice', 26),
#   ('See', 26),
#   ('out!', 25),
#   ('going.', 25),
#   ('car,', 25),
#   ('together.', 25),
#   ('huh?', 25),
#   ('way.', 25),
#   ('think?', 25),
#   ('best', 25),
#   ('anyone', 25),
#   ('sounds', 25),
#   ('meeting', 25),
#   ('stupid', 25),
#   ('relationship', 25),
#   ('friends', 25),
#   ('giving', 25),
#   ('house', 25),
#   ('break', 25),
#   ('says', 25),
#   ('job.', 25),
#   ('watching', 25),
#   ('matter', 25),
#   ("Elaine's", 25),
#   ('look,', 25),
#   ('see,', 24),
#   ('already', 24),
#   ('here!', 24),
#   ('ten', 24),
#   ('(He', 24),
#   ('bought', 24),
#   ('George?', 24),
#   ('Chinese', 24),
#   ('turn', 24),
#   ('himself)', 24),
#   ('enough', 24),
#   ('couple', 24),
#   ('Listen,', 24),
#   ('dinner', 24),
#   ('to.', 24),
#   ('man.', 24),
#   ('Sure.', 24),
#   ('eating', 24),
#   ("who's", 24),
#   ('"I', 24),
#   ('over.', 24),
#   ('on?', 24),
#   ("can't.", 24),
#   ("Where's", 24),
#   ('Hello', 24),
#   ('hey', 24),
#   ('theres', 23),
#   ('Theres', 23),
#   ('sorry,', 23),
#   ('opens', 23),
#   ('box', 23),
#   ('forgot', 23),
#   ('between', 23),
#   ('yourself', 23),
#   ('work.', 23),
#   ('listen,', 23),
#   ('picture', 23),
#   ('minutes', 23),
#   ('Tell', 23),
#   ('six', 23),
#   ('No!', 23),
#   ('done', 23),
#   ("how's", 23),
#   ('lost', 23),
#   ('hair', 23),
#   ('Newman', 23),
#   ('go?', 22),
#   ('shes', 22),
#   ('anyway.', 22),
#   ('sure?', 22),
#   ('show.', 22),
#   ('seem', 22),
#   ('Right.', 22),
#   ('likes', 22),
#   ('bit', 22),
#   ('Were', 22),
#   ('book', 22),
#   ('bet', 22),
#   ('Nah,', 22),
#   ('thanks', 22),
#   ('twenty', 22),
#   ('car?', 22),
#   ('people.', 22),
#   ('Uh', 22),
#   ('seems', 22),
#   ('For', 22),
#   ('kid', 22),
#   ('Right', 22),
#   ('Bye.', 22),
#   ('movie', 22),
#   ('walking', 22),
#   ('it)', 22),
#   ('Nothing.', 22),
#   ('jacket', 22),
#   ("George's", 22),
#   ('Too', 22),
#   ("Isn't", 22),
#   ('business.', 22),
#   ('hard', 22),
#   ('matter?', 22),
#   ('sex', 22),
#   ('See,', 21),
#   ('stuff', 21),
#   ('write', 21),
#   ('face', 21),
#   ('ahead.', 21),
#   ('walks', 21),
#   ('mother', 21),
#   ('Whats', 21),
#   ('tried', 21),
#   ('her,', 21),
#   ('friends.', 21),
#   ('Anyway,', 21),
#   ('water', 21),
#   ('time?', 21),
#   ('years.', 21),
#   ('fact,', 21),
#   ('But,', 21),
#   ('without', 21),
#   ('nice.', 21),
#   ('Joe', 21),
#   ('yeah', 21),
#   ('ya.', 21),
#   ('(pointing', 20),
#   ('girl', 20),
#   ('moving', 20),
#   ('house.', 20),
#   ('One', 20),
#   ('fact', 20),
#   ('deal', 20),
#   ('rest', 20),
#   ('do,', 20),
#   ('cut', 20),
#   ('along', 20),
#   ('run', 20),
#   ('understand.', 20),
#   ('late.', 20),
#   ('time,', 20),
#   ('set', 20),
#   ('course.', 20),
#   ('all.', 20),
#   ('away.', 20),
#   ('broke', 20),
#   ('bottle', 20),
#   ('deal.', 20),
#   ("doin'", 20),
#   ("You'll", 20),
#   ('what,', 20),
#   ('seeing', 20),
#   ('mention', 20),
#   ('us.', 20),
#   ('(on', 19),
#   ('cup', 19),
#   ('game', 19),
#   ('something?', 19),
#   ('different', 19),
#   ('hot', 19),
#   ('turns', 19),
#   ('in,', 19),
#   ('living', 19),
#   ('By', 19),
#   ('way,', 19),
#   ('money?', 19),
#   ('started', 19),
#   ('together', 19),
#   ('out)', 19),
#   ('change', 19),
#   ("'em.", 19),
#   ("C'mon,", 19),
#   ('you!', 19),
#   ('Actually,', 19),
#   ('thanks.', 19),
#   ('(hangs', 19),
#   ('(looking', 19),
#   ('home.', 18),
#   ('worst', 18),
#   ('second', 18),
#   ('lets', 18),
#   ('world', 18),
#   ('things.', 18),
#   ('job', 18),
#   ('naked', 18),
#   ('anything?', 18),
#   ('one?', 18),
#   ('Was', 18),
#   ('nobody', 18),
#   ('Hes', 18),
#   ('excuse', 18),
#   ('reason', 18),
#   ('Very', 18),
#   ('door,', 18),
#   ('As', 18),
#   ('With', 18),
#   ('pretend', 18),
#   ('People', 18),
#   ('throw', 18),
#   ('have.', 18),
#   ('kill', 18),
#   ('table', 18),
#   ('ready', 18),
#   ('street', 18),
#   ('sleep', 18),
#   ('shut', 18),
#   ('number', 18),
#   ("Can't", 18),
#   ('on!', 18),
#   ("Who's", 18),
#   ('missed', 18),
#   ("guy's", 18),
#   ("one's", 18),
#   ('oh', 18),
#   ('game.', 17),
#   ('them?', 17),
#   ('figure', 17),
#   ('Uh-huh.', 17),
#   ('notice', 17),
#   ('Two', 17),
#   ('question.', 17),
#   ('(pause)', 17),
#   ('felt', 17),
#   ('anybody', 17),
#   ('guy?', 17),
#   ('stand', 17),
#   ('black', 17),
#   ('cannot', 17),
#   ('back,', 17),
#   ('guy,', 17),
#   ('liked', 17),
#   ('about.', 17),
#   ('ticket', 17),
#   ('either.', 17),
#   ('pants', 17),
#   ('paper', 17),
#   ('night?', 17),
#   ('white', 17),
#   ('worked', 17),
#   ('Hold', 17),
#   ('everyone', 17),
#   ('listen', 17),
#   ("we've", 17),
#   ('day.', 17),
#   ('(Hangs', 17),
#   ('is?', 17),
#   ('important', 17),
#   ('Here', 17),
#   ('ah,', 17),
#   ('Kramer?', 17),
#   ("aren't", 17),
#   ('Ya', 17),
#   ('Who?', 17),
#   ('car!', 17),
#   ('keys', 17),
#   ("How's", 17),
#   ('ball', 17),
#   ('around,', 16),
#   ('again,', 16),
#   ('side', 16),
#   ('anything,', 16),
#   ('problem.', 16),
#   ('bathroom.', 16),
#   ('sits', 16),
#   ('glad', 16),
#   ('Um,', 16),
#   ('line', 16),
#   ('(thinking)', 16),
#   ('Shes', 16),
#   ('over?', 16),
#   ('fight', 16),
#   ('On', 16),
#   ('building.', 16),
#   ('Give', 16),
#   ('apartment.', 16),
#   ('Thanks.', 16),
#   ('hang', 16),
#   ('mind.', 16),
#   ('be?', 16),
#   ('up!', 16),
#   ('thousand', 16),
#   ('sometimes', 16),
#   ('in?', 16),
#   ('stuff.', 16),
#   ('catch', 16),
#   ('threw', 16),
#   ('store', 16),
#   ('whatever', 16),
#   ('her!', 16),
#   ('close', 16),
#   ('dollars', 16),
#   ('be.', 16),
#   ('top', 16),
#   ('mind?', 16),
#   ('well.', 16),
#   ('tomorrow', 16),
#   ('again?', 16),
#   ('story', 16),
#   ('uncle', 16),
#   ('Huh?', 16),
#   ('smell', 16),
#   ("don't.", 16),
#   ('doctor', 16),
#   ('George!', 16),
#   ('voice)', 16),
#   ('him)', 16),
#   ('standing', 15),
#   ('coffee.', 15),
#   ('Good.', 15),
#   ('amazing', 15),
#   ('number.', 15),
#   ('move.', 15),
#   ('human', 15),
#   ('tomorrow.', 15),
#   ('needs', 15),
#   ('them,', 15),
#   ('bag', 15),
#   ('want?', 15),
#   ('think,', 15),
#   ('noticed', 15),
#   ('book.', 15),
#   ('happy', 15),
#   ('friend.', 15),
#   ('course,', 15),
#   ('myself.', 15),
#   ('running', 15),
#   ('Jerry.', 15),
#   ('until', 15),
#   ('become', 15),
#   ('night,', 15),
#   ('keys.', 15),
#   ('certain', 15),
#   ('picks', 15),
#   ('today.', 15),
#   ('table.', 15),
#   ('head.', 15),
#   ('business', 15),
#   ('true.', 15),
#   ('I-I', 15),
#   ('Never', 15),
#   ('Does', 15),
#   ('asking', 15),
#   ('thing?', 15),
#   ('putting', 15),
#   ('touch', 15),
#   ('happened.', 15),
#   ('finally', 15),
#   ('think.', 15),
#   ('since', 15),
#   ('talked', 15),
#   ('off?', 15),
#   ('woman.', 15),
#   ('kept', 15),
#   ('hi.', 15),
#   ('sees', 15),
#   ('sure.', 15),
#   ('sound', 15),
#   ('taken', 15),
#   ('club', 15),
#   ('good,', 15),
#   ('looked', 15),
#   ('Aw,', 15),
#   ('so?', 15),
#   ('in)', 15),
#   ('lives', 15),
#   ("Didn't", 15),
#   ('shirt', 14),
#   ('ahead', 14),
#   ('trouble', 14),
#   ...],
#  'GEORGE': [('I', 3946),
#   ('the', 3136),
#   ('a', 2457),
#   ('to', 2287),
#   ('you', 2269),
#   ('of', 1033),
#   ('in', 923),
#   ('and', 922),
#   ('You', 879),
#   ("I'm", 823),
#   ('is', 809),
#   ('it', 786),
#   ('that', 763),
#   ('my', 706),
#   ('have', 646),
#   ('was', 644),
#   ('with', 631),
#   ('for', 605),
#   ('me', 600),
#   ('this', 573),
#   ('like', 543),
#   ('not', 532),
#   ('What', 520),
#   ('do', 518),
#   ('on', 515),
#   ('just', 497),
#   ("don't", 485),
#   ('know', 479),
#   ('be', 471),
#   ('get', 460),
#   ('what', 441),
#   ("It's", 415),
#   ('about', 404),
#   ('are', 383),
#   ('at', 378),
#   ('all', 371),
#   ('think', 371),
#   ('got', 367),
#   ('she', 361),
#   ('Oh,', 339),
#   ('out', 339),
#   ('Well,', 328),
#   ('it.', 326),
#   ('your', 324),
#   ('he', 323),
#   ('her', 312),
#   ('we', 306),
#   ('his', 301),
#   ('up', 298),
#   ("it's", 289),
#   ('see', 279),
#   ('gonna', 278),
#   ('they', 273),
#   ('me.', 272),
#   ('if', 270),
#   ('tell', 267),
#   ('go', 263),
#   ('could', 259),
#   ('Yeah,', 256),
#   ('no', 252),
#   ('uh,', 249),
#   ('The', 243),
#   ("can't", 240),
#   ('know,', 231),
#   ('going', 230),
#   ('really', 222),
#   ('can', 220),
#   ("That's", 216),
#   ('No,', 214),
#   ('All', 213),
#   ('had', 213),
#   ('an', 210),
#   ('so', 206),
#   ('So', 197),
#   ("I'll", 194),
#   ('from', 192),
#   ('This', 185),
#   ('She', 181),
#   ("you're", 181),
#   ('want', 180),
#   ('And', 180),
#   ('How', 175),
#   ('one', 175),
#   ('very', 173),
#   ('He', 171),
#   ('never', 170),
#   ('would', 170),
#   ('Hey,', 170),
#   ('how', 169),
#   ('but', 166),
#   ('Why', 166),
#   ('some', 166),
#   ('Yeah.', 163),
#   ("didn't", 163),
#   ('you.', 162),
#   ('Oh', 161),
#   ('did', 161),
#   ('little', 160),
#   ('-', 158),
#   ('back', 154),
#   ('him', 151),
#   ('.', 151),
#   ("that's", 150),
#   ('take', 150),
#   ('right', 147),
#   ('Well', 146),
#   ('It', 144),
#   ('good', 141),
#   ('there', 140),
#   ('gotta', 136),
#   ('as', 136),
#   ('me,', 132),
#   ('were', 132),
#   ('over', 131),
#   ('What?', 129),
#   ('right,', 127),
#   ('should', 127),
#   ('My', 127),
#   ('when', 125),
#   ('into', 123),
#   ('am', 123),
#   ('here.', 123),
#   ("You're", 123),
#   ("I've", 123),
#   ('Jerry,', 122),
#   ('Im', 119),
#   ('say', 119),
#   ('Jerry', 118),
#   ('look', 118),
#   ('They', 118),
#   ('been', 118),
#   ('said', 118),
#   ('So,', 117),
#   ('that?', 115),
#   ('that.', 114),
#   ('even', 113),
#   ('come', 112),
#   ('right.', 111),
#   ('No', 110),
#   ('know.', 108),
#   ('make', 108),
#   ('guy', 107),
#   ('We', 107),
#   ('something', 105),
#   ('it?', 104),
#   ('A', 103),
#   ('no,', 101),
#   ('down', 100),
#   ('you,', 98),
#   ('any', 98),
#   ('then', 97),
#   ('way', 97),
#   ('(to', 95),
#   ('them', 95),
#   ('me?', 94),
#   ('more', 94),
#   ('thing', 94),
#   ('need', 93),
#   ('or', 93),
#   ('George', 93),
#   ('But', 92),
#   ('this.', 91),
#   ('two', 91),
#   ('here', 91),
#   ('Is', 91),
#   ("What's", 91),
#   ('dont', 90),
#   ('call', 90),
#   ('believe', 89),
#   ('her.', 88),
#   ('time', 87),
#   ('Alright,', 87),
#   ('No.', 86),
#   ("doesn't", 86),
#   ('ever', 85),
#   ('If', 85),
#   ('big', 85),
#   ('told', 85),
#   ('there.', 85),
#   ('give', 84),
#   ('Do', 83),
#   ('doing', 83),
#   ('whole', 82),
#   ('...', 82),
#   ('has', 81),
#   ('wanna', 80),
#   ('by', 80),
#   ('talk', 80),
#   ('Yes,', 79),
#   ('why', 79),
#   ('these', 79),
#   ('off', 79),
#   ('who', 79),
#   ('because', 79),
#   ('I,', 79),
#   ('those', 79),
#   ('Jerry.', 78),
#   ('go.', 78),
#   ('ask', 77),
#   ('Maybe', 77),
#   ('love', 77),
#   ('Uh,', 75),
#   ('where', 75),
#   ('up.', 75),
#   ('you?', 74),
#   ('other', 74),
#   ('That', 74),
#   ("He's", 74),
#   ('woman', 73),
#   ('getting', 73),
#   ('than', 73),
#   ("she's", 73),
#   ("She's", 73),
#   ('Did', 72),
#   ('much', 72),
#   ('people', 72),
#   ('still', 72),
#   ("he's", 72),
#   ('out.', 71),
#   ('will', 71),
#   ('it,', 70),
#   ('good.', 70),
#   ('Jerry)', 70),
#   ('only', 70),
#   ('always', 70),
#   ('it!', 69),
#   ("we're", 69),
#   ('this?', 68),
#   ('around', 67),
#   ('let', 67),
#   ('talking', 66),
#   ('now', 65),
#   ('Mr.', 65),
#   ('hear', 64),
#   ("there's", 64),
#   ('put', 63),
#   ('does', 62),
#   ('mean', 62),
#   ('lot', 62),
#   ('feel', 61),
#   ('anything', 61),
#   ('Who', 61),
#   ('do?', 61),
#   ("Don't", 61),
#   ("what's", 61),
#   ('him.', 60),
#   ('Come', 59),
#   ('looking', 59),
#   ('What,', 59),
#   ('thought', 59),
#   ('Because', 58),
#   ('great', 58),
#   ('no.', 58),
#   ('made', 58),
#   ('yeah.', 58),
#   ('Are', 57),
#   ('kind', 57),
#   ('Just', 57),
#   ('too', 56),
#   ('Really?', 56),
#   ('Where', 56),
#   ('Of', 55),
#   ('find', 55),
#   ('back.', 55),
#   ('something.', 54),
#   ('what?', 54),
#   ('Elaine', 54),
#   ('on.', 54),
#   ("I'd", 54),
#   ("they're", 54),
#   ('time.', 53),
#   ('Hey', 53),
#   ('wanted', 52),
#   ('Now', 52),
#   ('last', 52),
#   ('maybe', 51),
#   ('Its', 51),
#   ('mean,', 51),
#   ('here?', 51),
#   ('yeah,', 50),
#   ("wouldn't", 50),
#   ('Hey.', 50),
#   ('show', 49),
#   ('Not', 49),
#   ('went', 49),
#   ('do.', 49),
#   ('first', 49),
#   ('gave', 48),
#   ('stop', 48),
#   ("let's", 48),
#   ('now.', 47),
#   ('new', 47),
#   ('Yes.', 47),
#   ('saw', 47),
#   ('cant', 46),
#   ('uh', 46),
#   ('here,', 46),
#   ('nice', 46),
#   ('another', 46),
#   ('work', 45),
#   ('meet', 45),
#   ('supposed', 45),
#   ('better', 45),
#   ('coffee', 45),
#   ('Kramer,', 45),
#   ("There's", 45),
#   ('car', 45),
#   ('course', 44),
#   ('their', 44),
#   ('Let', 43),
#   ('When', 43),
#   ('(To', 43),
#   ("They're", 43),
#   ('(he', 43),
#   ('Wait', 42),
#   ('wait', 42),
#   ('wants', 42),
#   ('might', 42),
#   ('well,', 42),
#   ('seen', 42),
#   ('Can', 42),
#   ('man', 42),
#   ('huh?', 42),
#   ('Ah,', 42),
#   ('sure', 41),
#   ('There', 41),
#   ('hell', 41),
#   ('took', 41),
#   ('me!', 41),
#   ('Excuse', 41),
#   ('up)', 41),
#   ('nothing', 40),
#   ('long', 40),
#   ('try', 40),
#   ('happened', 40),
#   ('help', 40),
#   ('Kramer', 40),
#   ('right?', 39),
#   ('on,', 39),
#   ('its', 39),
#   ('must', 39),
#   ('(George', 39),
#   ('is.', 39),
#   ('looks', 39),
#   ('trying', 39),
#   ('guess', 39),
#   ('us', 39),
#   ('Would', 39),
#   ('Like', 39),
#   ("Let's", 39),
#   ('buy', 39),
#   ('up,', 38),
#   ('having', 38),
#   ('heard', 38),
#   ('guys', 38),
#   ('(Jerry', 38),
#   ("We're", 38),
#   ('you!', 37),
#   ('Why?', 37),
#   ('guy.', 37),
#   ('in.', 37),
#   ('In', 37),
#   ('front', 37),
#   ('few', 37),
#   ('after', 37),
#   ('walk', 36),
#   ('for?', 36),
#   ('that,', 36),
#   ('too.', 36),
#   ('next', 36),
#   ('Thank', 36),
#   ('out,', 36),
#   ('same', 36),
#   ('old', 36),
#   ('real', 36),
#   ('Jerry!', 36),
#   ('Look', 35),
#   ('pay', 35),
#   ('No!', 35),
#   ('thing.', 35),
#   ('Elaine,', 35),
#   ('pretty', 35),
#   ('leave', 35),
#   ('pick', 35),
#   ('parents', 35),
#   ("couldn't", 35),
#   ('friend', 35),
#   ('gets', 34),
#   ('Ill', 34),
#   ('George.', 34),
#   ('this,', 34),
#   ('anything.', 34),
#   ('left', 34),
#   ('bad', 34),
#   ('makes', 34),
#   ('use', 34),
#   ('day', 34),
#   ('Susan', 34),
#   ('actually', 33),
#   ('Elaine.', 33),
#   ('funny', 33),
#   ('not.', 33),
#   ('keep', 33),
#   ('life', 33),
#   ('here!', 33),
#   ('night.', 33),
#   ('through', 33),
#   ('coming', 32),
#   ('phone', 32),
#   ('see,', 32),
#   ('walks', 32),
#   ('one.', 32),
#   ('again.', 32),
#   ('comes', 32),
#   ('our', 32),
#   ('name', 32),
#   ("'em", 32),
#   ('well', 31),
#   ('knew', 31),
#   ('not?', 31),
#   ('outta', 31),
#   ('Oh.', 31),
#   ('now?', 31),
#   ('hand', 31),
#   ('Good', 31),
#   ('things', 31),
#   ("wasn't", 31),
#   ('Yes', 31),
#   ('used', 31),
#   ('didnt', 30),
#   ('called', 30),
#   ('Now,', 30),
#   ('off.', 30),
#   ('saying', 30),
#   ('Get', 30),
#   ('being', 30),
#   ('away', 30),
#   ('probably', 30),
#   ('Hey!', 30),
#   ("Jerry's", 30),
#   ('eat', 29),
#   ('her?', 29),
#   ('wrong', 29),
#   ('nothing.', 29),
#   ("we'll", 29),
#   ('mother', 29),
#   ('says', 28),
#   ('there,', 28),
#   ('now,', 28),
#   ('uh...', 28),
#   ('taking', 28),
#   ('both', 28),
#   ('money', 28),
#   ('go,', 28),
#   ('asked', 28),
#   ('him?', 28),
#   ('remember', 28),
#   ('later.', 28),
#   ('telling', 28),
#   ('Yes!', 28),
#   ('live', 28),
#   ('doing?', 28),
#   (',', 28),
#   ('Okay.', 27),
#   ('going?', 27),
#   ('over.', 27),
#   ('kill', 27),
#   ('sitting', 27),
#   ('I-I', 27),
#   ('thank', 27),
#   ('head', 27),
#   ('every', 27),
#   ('sit', 27),
#   ("haven't", 27),
#   ('much.', 27),
#   ('door)', 26),
#   ('before', 26),
#   ('Elaine)', 26),
#   ('(laughs)', 26),
#   ('thinking', 26),
#   ('change', 26),
#   ('start', 26),
#   ('them.', 26),
#   ('making', 26),
#   ('think?', 26),
#   ('living', 26),
#   ('man.', 26),
#   ('read', 26),
#   ('move', 26),
#   ("won't", 26),
#   ('say,', 26),
#   ('--', 26),
#   ("isn't", 26),
#   ('everything', 26),
#   ('may', 25),
#   ('place', 25),
#   ('apartment.', 25),
#   ('understand', 25),
#   ('else', 25),
#   ('own', 25),
#   ('hands', 25),
#   ('life.', 25),
#   ('day.', 25),
#   ('dinner', 25),
#   ('Right.', 25),
#   ('great.', 25),
#   ('minute,', 25),
#   ('Okay,', 25),
#   ('someone', 25),
#   ('father', 25),
#   ('about?', 25),
#   ('ya', 25),
#   ('hate', 24),
#   ('Listen,', 24),
#   ('Look,', 24),
#   ('knows', 24),
#   ('started', 24),
#   ('fine.', 24),
#   ('Anyway,', 24),
#   ('Oh!', 24),
#   ('Could', 24),
#   ('Nothing.', 24),
#   ('check', 24),
#   ('say?', 24),
#   ('Here', 24),
#   ('youre', 23),
#   ('done', 23),
#   ('three', 23),
#   ('piece', 23),
#   ('there?', 23),
#   ('care', 23),
#   ('sex', 23),
#   ('hundred', 23),
#   ('ah,', 23),
#   ('years', 23),
#   ('Kramer.', 23),
#   ('under', 23),
#   ('mind', 23),
#   ('know?', 23),
#   ('down.', 23),
#   ('found', 23),
#   ('sir.', 23),
#   ('least', 22),
#   ('minute.', 22),
#   ('takes', 22),
#   ('met', 22),
#   ('Then', 22),
#   ('stand', 22),
#   ('way,', 22),
#   ('likes', 22),
#   ('George,', 22),
#   ('listen', 22),
#   ('anyone', 22),
#   ('nice.', 22),
#   ('eh,', 22),
#   ('Very', 22),
#   ('Big', 22),
#   ('many', 22),
#   ('in,', 21),
#   ('woman.', 21),
#   ('Thats', 21),
#   ('came', 21),
#   ('on?', 21),
#   ('way.', 21),
#   ('twenty', 21),
#   ('Have', 21),
#   ('second.', 21),
#   ('sort', 21),
#   ('break', 21),
#   ('tried', 21),
#   ('face.', 21),
#   ('word', 21),
#   ('like,', 21),
#   ('on!', 21),
#   ('to.', 21),
#   ('bought', 21),
#   ('about.', 21),
#   ("Can't", 21),
#   ('thinks', 21),
#   ('hey,', 21),
#   ('happen', 21),
#   ('in?', 20),
#   ('what,', 20),
#   ('happened?', 20),
#   ('point', 20),
#   ('felt', 20),
#   ('up?', 20),
#   ('her,', 20),
#   ('which', 20),
#   ('ten', 20),
#   ('all.', 20),
#   ('Take', 20),
#   ('funny.', 20),
#   ('without', 20),
#   ('him)', 20),
#   ('today.', 20),
#   ('', 20),
#   ('story.', 20),
#   ('For', 20),
#   ('did.', 20),
#   ('goes', 20),
#   ('moving', 20),
#   ('himself)', 20),
#   ('something,', 20),
#   ("Who's", 20),
#   ('best', 20),
#   ('working', 20),
#   ('ha', 20),
#   ("Where's", 20),
#   ('up!', 20),
#   ('Your', 20),
#   ('second', 19),
#   ('Youre', 19),
#   ('Hi,', 19),
#   ('sure.', 19),
#   ('turn', 19),
#   ('oh', 19),
#   ('each', 19),
#   ('anymore.', 19),
#   ('five', 19),
#   ('dollars.', 19),
#   ('guy?', 19),
#   ('Boy,', 19),
#   ('hold', 19),
#   ('dollars', 19),
#   ('Tell', 19),
#   ('deal', 19),
#   ('Never', 19),
#   ('mean?', 19),
#   ('wear', 19),
#   ('phone)', 19),
#   ('So?', 19),
#   ('sorry', 19),
#   ('car.', 19),
#   ('person', 19),
#   ('Mr', 19),
#   ('watch', 18),
#   ('Jerry?', 18),
#   ('Yeah', 18),
#   ('friend.', 18),
#   ('forget', 18),
#   ('meeting', 18),
#   ('behind', 18),
#   ('office', 18),
#   ('lost', 18),
#   ('him,', 18),
#   ('this!', 18),
#   ('room', 18),
#   ('play', 18),
#   ('eating', 18),
#   ('exactly', 18),
#   ('again,', 18),
#   ("you'll", 18),
#   ('myself', 18),
#   ('work.', 18),
#   ('broke', 18),
#   ('Give', 18),
#   ('speak', 18),
#   ('bald', 18),
#   ('Mrs.', 18),
#   ('Marisa', 18),
#   ('liked', 17),
#   ('stuff', 17),
#   ('(chuckles)', 17),
#   ('hit', 17),
#   ('women', 17),
#   ('matter', 17),
#   ('course.', 17),
#   ('am.', 17),
#   ('money.', 17),
#   ('please.', 17),
#   ('together.', 17),
#   ('bathroom.', 17),
#   ('going.', 17),
#   ('so.', 17),
#   ('show.', 17),
#   ('sorry,', 17),
#   ('idea.', 17),
#   ('kidding?', 17),
#   ('is,', 17),
#   ('good,', 17),
#   ('Go', 17),
#   ("shouldn't", 17),
#   ('excuse', 17),
#   ("How's", 17),
#   ('enough', 17),
#   ('hard', 17),
#   ('job', 17),
#   ('together', 17),
#   ('store', 17),
#   ('idea', 17),
#   ('Hi.', 17),
#   ('Ha', 17),
#   ('stay', 17),
#   ('(on', 16),
#   ('like?', 16),
#   ('rest', 16),
#   ('shes', 16),
#   ('sleep', 16),
#   ('bring', 16),
#   ('bathroom', 16),
#   ('call.', 16),
#   ('apartment', 16),
#   ('things.', 16),
#   ('different', 16),
#   ('and,', 16),
#   ('room.', 16),
#   ('seeing', 16),
#   ('while', 16),
#   ('God!', 16),
#   ('end', 16),
#   ('once', 16),
#   ('again', 16),
#   ('office.', 16),
#   ('her)', 16),
#   ('At', 16),
#   ('people.', 16),
#   ('beautiful', 16),
#   ('anybody', 16),
#   ('completely', 16),
#   ('somebody', 16),
#   ('Costanza.', 16),
#   ('waiting', 16),
#   ('Should', 16),
#   ('door', 16),
#   ('Chinese', 16),
#   ('full', 16),
#   ('Yeah!', 16),
#   ('question.', 16),
#   ('us.', 16),
#   ('candy', 16),
#   ('New', 15),
#   ('thats', 15),
#   ('time,', 15),
#   ('worked', 15),
#   ('bad.', 15),
#   ('(They', 15),
#   ('looked', 15),
#   ('picked', 15),
#   ('thousand', 15),
#   ('able', 15),
#   ('People', 15),
#   ('throw', 15),
#   ('Right', 15),
#   ('paid', 15),
#   ('home', 15),
#   ('Lloyd', 15),
#   ('stupid', 15),
#   ('problem', 15),
#   ('wearing', 15),
#   ('Thanks', 15),
#   ('already', 15),
#   ('done.', 15),
#   ('couple', 15),
#   ('sure,', 15),
#   ('hot', 15),
#   ('hope', 15),
#   ('With', 15),
#   ('Every', 15),
#   ('so,', 15),
#   ('Me', 15),
#   ("Kramer's", 15),
#   ('is?', 15),
#   ('friends', 15),
#   ('see.', 15),
#   ('bit', 15),
#   ('listen,', 14),
#   ('touch', 14),
#   ('oh,', 14),
#   ('table', 14),
#   ('Id', 14),
#   ('paper', 14),
#   ('watching', 14),
#   ('back,', 14),
#   ('close', 14),
#   ('place.', 14),
#   ('Listen', 14),
#   ('almost', 14),
#   ('One', 14),
#   ('minutes.', 14),
#   ('right!', 14),
#   ('home.', 14),
#   ('boy.', 14),
#   ('giving', 14),
#   ('such', 14),
#   ('yes,', 14),
#   ('mind.', 14),
#   ('Remember', 14),
#   ('most', 14),
#   ('job.', 14),
#   ('fact,', 14),
#   ('chocolate', 14),
#   ('..', 14),
#   ('everyone', 14),
#   ('face', 14),
#   ('minutes', 14),
#   ('shut', 14),
#   ("can't.", 14),
#   ('name.', 14),
#   ('car,', 14),
#   ('yeah', 14),
#   ('high', 14),
#   ("who's", 14),
#   ('plane', 14),
#   ('owe', 14),
#   ('car?', 14),
#   ('hey', 14),
#   ('days.', 14),
#   ('Nobody', 14),
#   ("You've", 14),
#   ('mine.', 14),
#   ('Steinbrenner', 14),
#   ('puts', 13),
#   ('God', 13),
#   ('spend', 13),
#   ('lets', 13),
#   ('open', 13),
#   ('out!', 13),
#   ('happened.', 13),
#   ('bother', 13),
#   ('guy,', 13),
#   ('out?', 13),
#   ('six', 13),
#   ('As', 13),
#   ('arms', 13),
#   ('hes', 13),
#   ('since', 13),
#   ('Too', 13),
#   ('Or', 13),
#   ('first.', 13),
#   ('said,', 13),
#   ('problem.', 13),
#   ('week.', 13),
#   ('standing', 13),
#   ('Alright', 13),
#   ('thing,', 13),
#   ('date', 13),
#   ('stole', 13),
#   ("We'll", 13),
#   ('down,', 13),
#   ('God.', 13),
#   ('house.', 13),
#   ('door,', 13),
#   ('drop', 13),
#   ('seem', 13),
#   ('quite', 13),
#   ('days', 13),
#   ('Who?', 13),
#   ('Was', 13),
#   ('(Elaine', 13),
#   ('people,', 13),
#   ('run', 13),
#   ('there!', 13),
#   ('Elaine?', 13),
#   ('fix', 13),
#   ('between', 13),
#   ("you've", 13),
#   ('he?', 13),
#   ('entire', 13),
#   ('deal.', 13),
#   ('sorry.', 13),
#   ('TV', 13),
#   ('(getting', 13),
#   ("Susan's", 13),
#   ("d'you", 13),
#   ('table)', 12),
#   ('Ive', 12),
#   ('go!', 12),
#   ('Besides,', 12),
#   ('lunch', 12),
#   ('us?', 12),
#   ('sick', 12),
#   ('yes.', 12),
#   ('well.', 12),
#   ('Some', 12),
#   ('until', 12),
#   ('(He', 12),
#   ('Please.', 12),
#   ('Please,', 12),
#   ('small', 12),
#   ('Something', 12),
#   ('happy', 12),
#   ('okay.', 12),
#   ('Elaine!', 12),
#   ('gives', 12),
#   ('Um,', 12),
#   ('um,', 12),
#   ('I...', 12),
#   ('four', 12),
#   ('off,', 12),
#   ('wedding', 12),
#   ('threw', 12),
#   ('Kramer)', 12),
#   ('important', 12),
#   ('These', 12),
#   ('what.', 12),
#   ('First', 12),
#   ('cost', 12),
#   ('yes', 12),
#   ('picture', 12),
#   ('nose', 12),
#   ('phone.', 12),
#   ("Isn't", 12),
#   ('Alright.', 12),
#   ('leave)', 12),
#   ('Hi', 12),
#   ('ha,', 12),
#   ('running', 12),
#   ('house', 12),
#   ('See,', 12),
#   ('Yeah?', 12),
#   ('(', 12),
#   ('bathroom)', 12),
#   ("Elaine's", 12),
#   ('Wow.', 12),
#   ('look,', 12),
#   ('around.', 12),
#   ('Huh?', 12),
#   ('notice', 12),
#   ('Christmas', 12),
#   ('starts', 12),
#   ('it)', 12),
#   ('playing', 12),
#   ('was,', 12),
#   ('chair', 12),
#   ('off)', 12),
#   ('eye', 12),
#   ('Susan.', 12),
#   ('out)', 12),
#   ('His', 12),
#   ('yada', 12),
#   ('calls', 11),
#   ('tomorrow', 11),
#   ('To', 11),
#   ('fingers)', 11),
#   ('night,', 11),
#   ('today', 11),
#   ('Theyre', 11),
#   ('story', 11),
#   ('minute', 11),
#   ('suppose', 11),
#   ('works', 11),
#   ('good?', 11),
#   ('back?', 11),
#   ('theres', 11),
#   ('change.', 11),
#   ('parking', 11),
#   ('else.', 11),
#   ('think.', 11),
#   ('turns', 11),
#   ('loved', 11),
#   ('letting', 11),
#   ('Shes', 11),
#   ('really.', 11),
#   ('thanks.', 11),
#   ('say.', 11),
#   ('fine', 11),
#   ('See', 11),
#   ('tonight.', 11),
#   ('yourself', 11),
#   ('head)', 11),
#   ('And,', 11),
#   ('late.', 11),
#   ('leaving', 11),
#   ('voice)', 11),
#   ('then,', 11),
#   ('mental', 11),
#   ('away.', 11),
#   ('late', 11),
#   ('morning.', 11),
#   ('sure?', 11),
#   ('mention', 11),
#   ('God,', 11),
#   ('part', 11),
#   ('laughing', 11),
#   ('Those', 11),
#   ('Fine.', 11),
#   ('less', 11),
#   ('leaves', 11),
#   ('lose', 11),
#   ('Kramer?', 11),
#   ('putting', 11),
#   ('complete', 11),
#   ('are.', 11),
#   ('kinda', 11),
#   ('Once', 11),
#   ('move.', 11),
#   ('fun', 11),
#   ('personal', 11),
#   ('Nothing', 11),
#   ('please', 11),
#   ('cool', 11),
#   ('set', 11),
#   ('afraid', 11),
#   ('Kramer!', 11),
#   ("You'll", 11),
#   ('to,', 11),
#   ('doctor', 11),
#   ('tape', 11),
#   ('side', 11),
#   ...],
#  'ELAINE': [('I', 2604),
#   ('the', 1797),
#   ('you', 1713),
#   ('a', 1557),
#   ('to', 1538),
#   ('and', 748),
#   ('is', 711),
#   ('of', 634),
#   ('that', 603),
#   ('You', 598),
#   ('in', 588),
#   ("I'm", 495),
#   ('it', 493),
#   ('Oh,', 490),
#   ('this', 464),
#   ('have', 458),
#   ('just', 444),
#   ('my', 438),
#   ('he', 429),
#   ('was', 416),
#   ('What', 398),
#   ("don't", 384),
#   ('with', 376),
#   ('for', 368),
#   ('me', 360),
#   ('on', 358),
#   ('do', 334),
#   ('know', 329),
#   ('are', 308),
#   ('at', 308),
#   ('not', 305),
#   ('Well,', 303),
#   ('what', 290),
#   ('like', 282),
#   ('be', 275),
#   ('get', 269),
#   ('her', 265),
#   ('got', 261),
#   ('your', 259),
#   ('about', 258),
#   ('Yeah,', 246),
#   ('think', 245),
#   ('so', 240),
#   ('we', 238),
#   ('out', 230),
#   ("It's", 220),
#   ('up', 216),
#   ("it's", 209),
#   ('No,', 200),
#   ('it.', 196),
#   ('going', 195),
#   ('his', 195),
#   ('gonna', 191),
#   ('What?', 189),
#   ('Oh', 187),
#   ('really', 181),
#   ('go', 181),
#   ('know,', 179),
#   ('can', 178),
#   ('all', 177),
#   ('him', 171),
#   ('did', 170),
#   ("can't", 168),
#   ('see', 165),
#   ('they', 160),
#   ('if', 160),
#   ('Yeah.', 157),
#   ('want', 152),
#   ('He', 152),
#   ('she', 152),
#   ('So', 151),
#   ('but', 150),
#   ('me.', 146),
#   ('an', 143),
#   ("I'll", 143),
#   ('were', 141),
#   ('one', 140),
#   ("he's", 138),
#   ('no', 134),
#   ('And', 130),
#   ('tell', 130),
#   ("didn't", 129),
#   ("you're", 129),
#   ('come', 128),
#   ("that's", 128),
#   ('The', 127),
#   ('How', 127),
#   ('Hey,', 125),
#   ('how', 124),
#   ('you.', 124),
#   ('from', 124),
#   ('Jerry,', 123),
#   ("That's", 116),
#   ('could', 115),
#   ('had', 115),
#   ('some', 114),
#   ('would', 112),
#   ('Well', 112),
#   ('This', 111),
#   ('right', 111),
#   ('am', 111),
#   ('as', 109),
#   ('little', 108),
#   ('no,', 107),
#   ('mean,', 107),
#   ('Why', 106),
#   ("I've", 106),
#   ('It', 105),
#   ('it?', 105),
#   ("He's", 105),
#   ('.', 105),
#   ('know.', 103),
#   ('should', 102),
#   ('never', 100),
#   ('take', 98),
#   ('look', 98),
#   ('over', 98),
#   ('So,', 97),
#   ('Jerry', 96),
#   ('been', 96),
#   ('very', 95),
#   ('Mr.', 95),
#   ('All', 94),
#   ("You're", 92),
#   ('who', 90),
#   ('there', 90),
#   ('then', 90),
#   ('No.', 88),
#   ('George', 88),
#   ('-', 88),
#   ('that?', 87),
#   ('here', 86),
#   ('(to', 86),
#   ('back', 84),
#   ('here.', 82),
#   ('mean', 82),
#   ('when', 81),
#   ('No', 80),
#   ('right.', 80),
#   ('good', 79),
#   ('But', 79),
#   ('has', 78),
#   ('That', 77),
#   ('him.', 77),
#   ('into', 75),
#   ('guy', 75),
#   ('uh,', 74),
#   ('this.', 73),
#   ('that.', 72),
#   ('Uh,', 72),
#   ('getting', 71),
#   ('because', 71),
#   ('said', 71),
#   ('say', 71),
#   ('these', 70),
#   ('We', 70),
#   ('what?', 69),
#   ('gotta', 69),
#   ('...', 69),
#   ('big', 68),
#   ('any', 68),
#   ('even', 68),
#   ('by', 67),
#   ('Do', 67),
#   ('Oh.', 67),
#   ('ha', 67),
#   ('make', 66),
#   ('told', 66),
#   ('Kramer,', 66),
#   ('you?', 65),
#   ('need', 65),
#   ('believe', 65),
#   ('or', 65),
#   ('something', 63),
#   ('off', 63),
#   ("What's", 63),
#   ('George,', 62),
#   ('put', 62),
#   ('yeah,', 61),
#   ('doing', 60),
#   ('thought', 60),
#   ("we're", 60),
#   ('why', 59),
#   ('down', 59),
#   ('me,', 57),
#   ('this?', 57),
#   ('give', 57),
#   ('Jerry)', 57),
#   ('it!', 56),
#   ('My', 56),
#   ('more', 56),
#   ('call', 56),
#   ('ever', 55),
#   ('A', 54),
#   ('does', 54),
#   ('Jerry.', 54),
#   ("doesn't", 54),
#   ('Okay,', 53),
#   ('time', 53),
#   ('up.', 53),
#   ('go.', 53),
#   ('Oh!', 53),
#   ('no.', 52),
#   ('it,', 52),
#   ('around', 52),
#   ('Hey.', 52),
#   ('two', 51),
#   ('Is', 51),
#   ('Alright,', 51),
#   ('here?', 50),
#   ('out.', 50),
#   ('right,', 50),
#   ('other', 50),
#   ('well,', 50),
#   ('Who', 50),
#   ('She', 49),
#   ('thing', 49),
#   ('Um,', 49),
#   ('Why?', 49),
#   ('Im', 48),
#   ('people', 48),
#   ('Are', 48),
#   ('me?', 48),
#   ('talk', 48),
#   ('Did', 48),
#   ('much', 48),
#   ('you,', 47),
#   ('do?', 47),
#   ('They', 47),
#   ('wanna', 47),
#   ('last', 46),
#   ('anything', 46),
#   ('now', 46),
#   ('on.', 46),
#   ('Come', 46),
#   ('went', 46),
#   ('kind', 46),
#   ('too', 46),
#   ('new', 46),
#   ('still', 46),
#   ('them', 45),
#   ('Hi.', 44),
#   ('yeah.', 44),
#   ('Where', 44),
#   ('guess', 43),
#   ('work', 43),
#   ('Just', 43),
#   ('on,', 43),
#   ('Can', 43),
#   ('Kramer', 43),
#   ('Hey', 43),
#   ('Elaine', 42),
#   ('well', 42),
#   ('good.', 42),
#   ('talking', 41),
#   ('dont', 41),
#   ('where', 41),
#   ('um,', 41),
#   ('find', 41),
#   ('Yes,', 41),
#   ('sure', 41),
#   ('us', 41),
#   ('Get', 40),
#   ('those', 39),
#   ('meet', 39),
#   ('friend', 39),
#   ('George.', 38),
#   ('pick', 38),
#   ("wouldn't", 38),
#   ('their', 37),
#   ('love', 37),
#   ('Because', 37),
#   ('nice', 37),
#   ('hear', 37),
#   ('looks', 37),
#   ('ask', 37),
#   ('being', 37),
#   ('way', 37),
#   ('called', 37),
#   ('there.', 36),
#   ('Hi,', 36),
#   ('Really?', 36),
#   ('Ah,', 36),
#   ("couldn't", 36),
#   ('whole', 36),
#   ('Okay.', 35),
#   ('If', 35),
#   ("there's", 35),
#   ('took', 35),
#   ('man', 34),
#   ('maybe', 34),
#   ("Don't", 34),
#   ('saw', 33),
#   ('great', 33),
#   ('always', 33),
#   ('guys', 33),
#   ("I'd", 33),
#   ("she's", 33),
#   ('woman', 33),
#   ('Jerry!', 32),
#   ('looking', 32),
#   ('back.', 32),
#   ('Look', 32),
#   ('stop', 32),
#   ('let', 32),
#   ("they're", 32),
#   ('pretty', 31),
#   ('sorry.', 31),
#   ('might', 31),
#   ('first', 31),
#   ('only', 31),
#   ('Hey!', 31),
#   ('wait', 30),
#   ('long', 30),
#   ('better', 30),
#   ('listen', 30),
#   ('lot', 30),
#   ('him?', 30),
#   ('such', 30),
#   ('Kramer.', 30),
#   ('I,', 30),
#   ('three', 30),
#   ("let's", 30),
#   ('seen', 29),
#   ('right?', 29),
#   ('made', 29),
#   ('her.', 29),
#   ('happened', 29),
#   ('thank', 29),
#   ("what's", 29),
#   ('(she', 29),
#   ('will', 29),
#   ('coming', 28),
#   ('No!', 28),
#   ('now.', 28),
#   ('its', 28),
#   ('Listen,', 28),
#   ('George)', 28),
#   ('trying', 28),
#   ('Maybe', 28),
#   ('time.', 28),
#   ('feel', 28),
#   ("They're", 28),
#   ('than', 28),
#   ('anyone', 27),
#   ('say?', 27),
#   ('sorry', 27),
#   ('gave', 27),
#   ('next', 27),
#   ('hate', 27),
#   ('through', 27),
#   ('There', 27),
#   ("won't", 27),
#   ('Hi', 27),
#   ("She's", 27),
#   ('Yeah', 27),
#   ('place', 26),
#   ('left', 26),
#   ('Thank', 26),
#   ('sit', 26),
#   ('there?', 26),
#   ('Now', 26),
#   ('keep', 26),
#   ('having', 26),
#   ('every', 26),
#   ('must', 26),
#   ('met', 25),
#   ('use', 25),
#   ('things', 25),
#   ('something.', 25),
#   ('stupid', 25),
#   ('them.', 25),
#   ('doing?', 25),
#   ('Of', 25),
#   ("Let's", 25),
#   ('George?', 25),
#   ('happened?', 25),
#   ('is.', 25),
#   ('Jerry?', 24),
#   ('this,', 24),
#   ('Excuse', 24),
#   ('huh?', 24),
#   ('our', 24),
#   ('one.', 24),
#   ("isn't", 24),
#   ('up)', 24),
#   ('anything.', 24),
#   ('(To', 24),
#   ("who's", 24),
#   ("We're", 24),
#   ('real', 24),
#   ('phone', 24),
#   ('Have', 23),
#   ('guy.', 23),
#   ('Ill', 23),
#   ('These', 23),
#   ('same', 23),
#   ('bad', 23),
#   ('Then', 23),
#   ('nothing.', 23),
#   ('him,', 23),
#   ('wanted', 23),
#   ('God.', 23),
#   ('too.', 23),
#   ('car', 23),
#   ('listen,', 23),
#   ('Mr', 23),
#   ('(Jerry', 22),
#   ('another', 22),
#   ('here,', 22),
#   ('someone', 22),
#   ('What,', 22),
#   ('car.', 22),
#   ('again.', 22),
#   ('name', 22),
#   ('thing.', 22),
#   ('phone)', 22),
#   ("There's", 22),
#   ('Not', 22),
#   ('In', 21),
#   ('so.', 21),
#   ('(laughs)', 21),
#   ('move', 21),
#   ('(looking', 21),
#   ('me!', 21),
#   ('okay?', 21),
#   ('Yes.', 21),
#   ('away', 21),
#   ('actually', 21),
#   ('man.', 21),
#   ('fine.', 21),
#   ('walk', 21),
#   ('sitting', 21),
#   ('comes', 21),
#   ('Elaine.', 21),
#   ('making', 21),
#   ('buy', 21),
#   ('remember', 20),
#   ("Jerry's", 20),
#   ('apartment', 20),
#   ('after', 20),
#   ('nothing', 20),
#   ('wants', 20),
#   ('before', 20),
#   ('asked', 20),
#   ('sorry,', 20),
#   ('enough', 20),
#   ('heard', 20),
#   ('care', 20),
#   ('Peterman,', 20),
#   ('idea', 19),
#   ('Its', 19),
#   ('used', 19),
#   ('said,', 19),
#   ('Kramer!', 19),
#   ('thinks', 19),
#   ('day.', 19),
#   ('funny.', 19),
#   ('says', 19),
#   ('pay', 19),
#   ('few', 19),
#   ('Let', 19),
#   ('head', 19),
#   ('show', 19),
#   ('wearing', 19),
#   ('now,', 18),
#   ('live', 18),
#   ('door', 18),
#   ('walks', 18),
#   ('(She', 18),
#   ('uh...', 18),
#   ('not.', 18),
#   ('leave', 18),
#   ('about?', 18),
#   ('course', 18),
#   ('Anyway,', 18),
#   ('did.', 18),
#   ('Look,', 18),
#   ('coffee', 18),
#   ('Hello.', 18),
#   ('Would', 18),
#   ('When', 18),
#   ('Huh.', 18),
#   ('do.', 18),
#   ('hold', 18),
#   ('front', 18),
#   ('under', 18),
#   ('bring', 18),
#   ('talked', 18),
#   ('wrong', 18),
#   ('wear', 18),
#   ('So?', 18),
#   ("'em.", 18),
#   ('hu', 18),
#   ('Peterman', 18),
#   ('walking', 17),
#   ('(Elaine', 17),
#   ('Kramer)', 17),
#   ('idea.', 17),
#   ('supposed', 17),
#   ('came', 17),
#   ('in.', 17),
#   ('But,', 17),
#   ('then,', 17),
#   ('gets', 17),
#   ('See,', 17),
#   ('on!', 17),
#   ('taking', 17),
#   ("wasn't", 17),
#   ('hi', 17),
#   ('office.', 17),
#   ('found', 17),
#   ('Yeah!', 17),
#   ('face', 17),
#   ('Yes', 17),
#   ('Uh', 17),
#   ('shut', 17),
#   ('hair', 16),
#   ('Good', 16),
#   ('eat', 16),
#   ('break', 16),
#   ('least', 16),
#   ('this!', 16),
#   ('much.', 16),
#   ('telling', 16),
#   ('hit', 16),
#   ('way.', 16),
#   ('Like', 16),
#   ('Right.', 16),
#   ('own', 16),
#   ('going?', 16),
#   ('out!', 16),
#   ('everything', 16),
#   ('somebody', 16),
#   ('great.', 16),
#   ('ya', 16),
#   ('problem', 16),
#   ("Who's", 16),
#   ("'em", 16),
#   ('door)', 16),
#   ('Yeah?', 16),
#   ('goes', 16),
#   ('call.', 16),
#   ('up?', 16),
#   ('Hello?', 16),
#   ('god,', 16),
#   (',', 16),
#   ("you've", 16),
#   ('off.', 16),
#   ('nice.', 16),
#   ("we'll", 16),
#   ('--', 16),
#   ('her,', 16),
#   ('hell', 16),
#   ('change', 16),
#   ('Sue', 16),
#   ('night', 15),
#   ('lost', 15),
#   ('guy,', 15),
#   ('Your', 15),
#   ('hundred', 15),
#   ('high', 15),
#   ('starts', 15),
#   ('uh', 15),
#   ('each', 15),
#   ('woman.', 15),
#   ('him)', 15),
#   ('night.', 15),
#   ('see,', 15),
#   ('New', 15),
#   ('on?', 15),
#   ('five', 15),
#   ('money', 15),
#   ('probably', 15),
#   ('help', 15),
#   ('okay.', 15),
#   ('know?', 15),
#   ('for?', 15),
#   ('Wait', 15),
#   ('please', 15),
#   ("haven't", 15),
#   ("Isn't", 15),
#   ('what,', 15),
#   ('home.', 15),
#   ('baby.', 15),
#   ('yeah', 15),
#   ('best', 15),
#   ('calling', 15),
#   ('ha.', 15),
#   ("gettin'", 15),
#   ('hand', 15),
#   ('Peterman.', 15),
#   ('parents', 14),
#   ('up,', 14),
#   ('day', 14),
#   ('God,', 14),
#   ('hot', 14),
#   ('oh,', 14),
#   ('hi,', 14),
#   ('takes', 14),
#   ('once', 14),
#   ('Huh?', 14),
#   ('god.', 14),
#   ('run', 14),
#   ('saying', 14),
#   ('forget', 14),
#   ('down.', 14),
#   ('away.', 14),
#   ('thanks', 14),
#   ('again', 14),
#   ('night?', 14),
#   ('thousand', 14),
#   ('matter', 14),
#   ('food', 14),
#   ('something?', 14),
#   ('movie', 14),
#   ('not?', 14),
#   ('try', 14),
#   ('dog', 14),
#   ("We'll", 14),
#   ("Where's", 14),
#   ("You've", 14),
#   ('looked', 14),
#   ('is,', 14),
#   ('her?', 14),
#   ('old', 14),
#   ('you!', 14),
#   ('David', 14),
#   ('think?', 13),
#   ('(pause)', 13),
#   ('totally', 13),
#   ('turns', 13),
#   ('father', 13),
#   ('so,', 13),
#   ('else', 13),
#   ('cant', 13),
#   ('Yes!', 13),
#   ('ran', 13),
#   ('years', 13),
#   ('know...', 13),
#   ('to.', 13),
#   ('while', 13),
#   ('drive', 13),
#   ('running', 13),
#   ('knew', 13),
#   ('problem.', 13),
#   ('friends.', 13),
#   ('between', 13),
#   ('bad.', 13),
#   ('close', 13),
#   ('doctor', 13),
#   ('order', 13),
#   ('mean?', 13),
#   ('Was', 13),
#   ('up!', 13),
#   ('go?', 13),
#   ('start', 13),
#   ('working', 13),
#   ('lunch', 13),
#   ('out?', 13),
#   ('Ha', 13),
#   ('ya.', 13),
#   ('Hi!', 13),
#   ('giving', 13),
#   ('way,', 13),
#   ('women', 13),
#   ('work.', 13),
#   ('thanks.', 13),
#   ('number', 13),
#   ('like,', 13),
#   ("What'd", 13),
#   ('sure.', 13),
#   ('down)', 13),
#   ('I...', 13),
#   ('(looks', 13),
#   ("d'you", 13),
#   ('didnt', 12),
#   ('before.', 12),
#   ('quite', 12),
#   ('Here,', 12),
#   ('cannot', 12),
#   ('four', 12),
#   ('Tell', 12),
#   ('hard', 12),
#   ('person', 12),
#   ('understand', 12),
#   ('watch', 12),
#   ('anymore.', 12),
#   ('tonight.', 12),
#   ('felt', 12),
#   ('Five', 12),
#   ('which', 12),
#   ('Boy,', 12),
#   ('Lippman', 12),
#   ('book', 12),
#   ('(Kramer', 12),
#   ('it)', 12),
#   ('that,', 12),
#   ('guy?', 12),
#   ('Alright.', 12),
#   ("you'll", 12),
#   ('Shut', 12),
#   ('hands', 12),
#   ('(quietly)', 12),
#   ('O.K.', 12),
#   ('likes', 12),
#   ('Ok,', 12),
#   ('hi.', 12),
#   ('later.', 12),
#   ('One', 12),
#   ('Wow!', 12),
#   ('bet', 12),
#   ('Ah.', 12),
#   ('and,', 12),
#   ('end', 12),
#   ('wish', 12),
#   ('today.', 12),
#   ('happen', 12),
#   ('Mrs.', 12),
#   ('second.', 12),
#   ('Pitt,', 12),
#   ('funny', 11),
#   ('there,', 11),
#   ('part', 11),
#   ('couple', 11),
#   ('without', 11),
#   ('For', 11),
#   ('okay,', 11),
#   ('paper', 11),
#   ('Youre', 11),
#   ('sounds', 11),
#   ('side', 11),
#   ('time?', 11),
#   ('behind', 11),
#   ('exactly', 11),
#   ('Mmm,', 11),
#   ('Now,', 11),
#   ('reading', 11),
#   ('everyone', 11),
#   ('why?', 11),
#   ('Right', 11),
#   ('Wow.', 11),
#   ('George!', 11),
#   ('stay', 11),
#   ('everybody', 11),
#   ('eating', 11),
#   ('herself)', 11),
#   ('Ya', 11),
#   ('word', 11),
#   ('What?!', 11),
#   ('Take', 11),
#   ('forgot', 11),
#   ('Joe', 11),
#   ('room', 11),
#   ('date.', 11),
#   ('please.', 11),
#   ('air', 11),
#   ('turn', 11),
#   ('fun', 11),
#   ('them,', 11),
#   ('mention', 11),
#   ('worked', 11),
#   ('using', 11),
#   ('return', 11),
#   ('(', 11),
#   ('Thanks', 11),
#   ('leave)', 11),
#   ('in,', 11),
#   ('go,', 11),
#   ('started', 11),
#   ('do,', 11),
#   ('puts', 11),
#   ('job', 11),
#   ('fine,', 11),
#   ('oh', 11),
#   ('(pointing', 11),
#   ('playing', 11),
#   ('completely', 11),
#   ('thinking', 11),
#   ('sent', 11),
#   ('mind', 11),
#   ('away)', 11),
#   ('Stop', 11),
#   ('David,', 11),
#   ('house', 10),
#   ('Nothing.', 10),
#   ('youre', 10),
#   ('gimme', 10),
#   ('dinner', 10),
#   ('hope', 10),
#   ('understand.', 10),
#   ('means', 10),
#   ('bought', 10),
#   ('And,', 10),
#   ('money.', 10),
#   ('Fine.', 10),
#   ('mine.', 10),
#   ('back?', 10),
#   ('twenty', 10),
#   ('different', 10),
#   ('almost', 10),
#   ('broke', 10),
#   ('life', 10),
#   ('stand', 10),
#   ('years.', 10),
#   ('Nice', 10),
#   ('look.', 10),
#   ('all.', 10),
#   ('he?', 10),
#   ('God', 10),
#   ('office', 10),
#   ('Kramer?', 10),
#   ('please,', 10),
#   ('people.', 10),
#   ('Could', 10),
#   ('excuse', 10),
#   ('seem', 10),
#   ('deal', 10),
#   ('days.', 10),
#   ('John', 10),
#   ('OK,', 10),
#   ('Remember', 10),
#   ('time,', 10),
#   ("aren't", 10),
#   ('plane', 10),
#   ('done', 10),
#   ('that!', 10),
#   ('name?', 10),
#   ('six', 10),
#   ('minute.', 10),
#   ('number.', 10),
#   ('half', 10),
#   ('life.', 10),
#   ('read', 10),
#   ('across', 10),
#   ('is?', 10),
#   ('thing?', 10),
#   ('stuff', 10),
#   ('out,', 10),
#   ('face.', 10),
#   ('good,', 10),
# ...
#   ('out', 259),
#   ('his', 256),
#   ('do', 255),
#   ('gonna', 250),
#   ('are', 246),
#   ('he', 245),
#   ('all', 240),
#   ("It's", 239),
#   ('up', 227),
#   ('Hey,', 226),
#   ('it.', 225),
#   ("it's", 220),
#   ('Jerry,', 217),
#   ('we', 201),
#   ('not', 197),
#   ('know,', 195),
#   ('they', 195),
#   ('What', 187),
#   ('Yeah.', 186),
#   ('No,', 185),
#   ('going', 184),
#   ('about', 178),
#   ("I'll", 177),
#   ('uh,', 176),
#   ("you're", 172),
#   ('Oh', 166),
#   ('The', 162),
#   ('want', 160),
#   ('can', 159),
#   ('go', 155),
#   ("that's", 155),
#   ('think', 153),
#   ('see', 148),
#   ('All', 146),
#   ('some', 143),
#   ('no', 143),
#   ('if', 142),
#   ('him', 140),
#   ('Well', 140),
#   ('me.', 134),
#   ('gotta', 134),
#   ('one', 133),
#   ('but', 131),
#   ('from', 130),
#   ('come', 129),
#   ('right', 127),
#   ('take', 127),
#   ('And', 125),
#   ("can't", 124),
#   ("That's", 124),
#   ('so', 123),
#   ('Jerry.', 122),
#   ('you.', 119),
#   ('she', 119),
#   ('yeah,', 119),
#   ('had', 113),
#   ('her', 113),
#   ('yeah.', 112),
#   ('no,', 112),
#   ('back', 111),
#   ("he's", 111),
#   ('there', 108),
#   ('tell', 108),
#   ('Hey.', 108),
#   ('-', 108),
#   ('So', 106),
#   ('an', 106),
#   ('over', 104),
#   ('Jerry', 104),
#   ('how', 104),
#   ('right,', 104),
#   ('little', 97),
#   ('He', 95),
#   ('down', 87),
#   ('very', 87),
#   ('look', 87),
#   ('into', 85),
#   ("didn't", 85),
#   ('really', 84),
#   ("I've", 83),
#   ('need', 81),
#   ('by', 80),
#   ('here', 80),
#   ('as', 80),
#   ('Come', 80),
#   ('big', 79),
#   ('huh?', 78),
#   ('any', 77),
#   ("He's", 77),
#   ('Hey', 76),
#   ('Uh,', 76),
#   ('these', 76),
#   ('Look', 76),
#   ('(to', 75),
#   ('no.', 75),
#   ('here.', 75),
#   ('when', 75),
#   ('been', 74),
#   ('off', 74),
#   ('No', 74),
#   ('Now', 74),
#   ('could', 73),
#   ('were', 72),
#   ('But', 72),
#   ('did', 72),
#   ('good', 70),
#   ('make', 69),
#   ('This', 69),
#   ("You're", 69),
#   ('that.', 68),
#   ('right.', 67),
#   ('you?', 67),
#   ('How', 66),
#   ('would', 66),
#   ('Alright,', 66),
#   ('on,', 65),
#   ('well,', 64),
#   ('They', 64),
#   ('A', 63),
#   ('then', 63),
#   ('So,', 63),
#   ('It', 63),
#   ('should', 62),
#   ('What?', 62),
#   ('around', 62),
#   ('let', 62),
#   ("we're", 62),
#   ('well', 61),
#   ('never', 61),
#   ('those', 61),
#   ('guy', 61),
#   ('now', 61),
#   ('told', 60),
#   ('there.', 60),
#   ('you,', 59),
#   ('this.', 59),
#   ('out.', 59),
#   ('two', 58),
#   ('way', 58),
#   ("she's", 58),
#   ('buddy.', 58),
#   ('Im', 57),
#   ('who', 57),
#   ('give', 57),
#   ('George', 57),
#   ('back.', 56),
#   ('it,', 56),
#   ('put', 56),
#   ('time', 56),
#   ('No.', 56),
#   ('George,', 55),
#   ('Now,', 54),
#   ('him.', 53),
#   ('where', 53),
#   ('even', 53),
#   ('My', 53),
#   ("What's", 53),
#   ('Jerry)', 52),
#   ('more', 52),
#   ('it?', 52),
#   ('Why', 52),
#   ("Jerry's", 52),
#   ('Ah,', 52),
#   ('.', 52),
#   ('why', 51),
#   ('...', 51),
#   ('say', 50),
#   ('thought', 50),
#   ('them', 50),
#   ('If', 49),
#   ('Yeah', 49),
#   ('wanna', 49),
#   ('something', 49),
#   ('on.', 49),
#   ('now.', 49),
#   ("they're", 49),
#   ('has', 49),
#   ('up.', 47),
#   ('am', 47),
#   ('or', 47),
#   ('go.', 47),
#   ('me,', 47),
#   ('Look,', 46),
#   ("what's", 46),
#   ('That', 46),
#   ('Hey!', 46),
#   ('We', 45),
#   ('new', 45),
#   ('thing', 45),
#   ('went', 45),
#   ('She', 45),
#   ('said', 44),
#   ('better', 44),
#   ('because', 44),
#   ('talk', 43),
#   ('whole', 43),
#   ("Don't", 43),
#   ('keep', 42),
#   ('(Jerry', 41),
#   ('still', 41),
#   ('saw', 41),
#   ("She's", 41),
#   ('Jerry!', 40),
#   ('See,', 40),
#   ('Elaine,', 40),
#   ('doing', 40),
#   ("They're", 40),
#   ('people', 39),
#   ('Kramer', 39),
#   ('much', 39),
#   ('mean,', 39),
#   ('looking', 39),
#   ('Because', 39),
#   ('know.', 39),
#   ("there's", 39),
#   ('their', 38),
#   ('ever', 38),
#   ('too', 38),
#   ('love', 37),
#   ('Elaine', 37),
#   ('Do', 36),
#   ('maybe', 36),
#   ('getting', 36),
#   ('here,', 36),
#   ('last', 35),
#   ('than', 35),
#   ('Oh.', 35),
#   ('lot', 35),
#   ('(Kramer', 35),
#   ('(To', 35),
#   ('time.', 35),
#   ('her.', 34),
#   ('--', 34),
#   ("doesn't", 34),
#   ("let's", 34),
#   ('hey,', 33),
#   ('talking', 33),
#   ("We're", 33),
#   ('other', 33),
#   ('good.', 33),
#   ('next', 33),
#   ('door)', 33),
#   ('Just', 33),
#   ("I'd", 33),
#   ('up,', 33),
#   ('Kramer.', 33),
#   ('great', 32),
#   ('feel', 32),
#   ('man.', 32),
#   ("wouldn't", 32),
#   ('our', 32),
#   ('made', 31),
#   ('Is', 31),
#   ('What,', 31),
#   ('one.', 31),
#   ('ya', 31),
#   ('(he', 31),
#   ('came', 30),
#   ('call', 30),
#   ('friend', 30),
#   ('Newman', 30),
#   ('coffee', 30),
#   ('another', 30),
#   ('mean', 30),
#   ("There's", 30),
#   ('us', 30),
#   ('dont', 29),
#   ('phone', 29),
#   ('yeah', 29),
#   ('took', 29),
#   ('three', 29),
#   ('every', 29),
#   ('man', 29),
#   ('says', 29),
#   ("you've", 29),
#   ('only', 29),
#   ('find', 28),
#   ('there,', 28),
#   ('George.', 28),
#   ('place', 28),
#   ('it!', 28),
#   ('pick', 28),
#   ('now,', 28),
#   ('stop', 28),
#   ('Are', 28),
#   ('that?', 28),
#   ('guys', 28),
#   ('Did', 28),
#   ('looks', 28),
#   ('Not', 28),
#   (',', 28),
#   ('I,', 27),
#   ('Yeah!', 27),
#   ('hey', 27),
#   ('hit', 27),
#   ('wants', 27),
#   ('help', 27),
#   ('wear', 27),
#   ('seen', 27),
#   ("'em", 27),
#   ('comes', 27),
#   ('you!', 27),
#   ('will', 27),
#   ('me!', 27),
#   ('here?', 27),
#   ('Yes,', 27),
#   ('guess', 27),
#   ('this,', 26),
#   ('in.', 26),
#   ('Okay,', 26),
#   ('use', 26),
#   ('through', 26),
#   ('after', 26),
#   ('ah,', 26),
#   ('nothing', 26),
#   ("we'll", 26),
#   ('These', 26),
#   ('always', 26),
#   ('listen,', 26),
#   ('own', 25),
#   ('check', 25),
#   ('believe', 25),
#   ('taking', 25),
#   ('do?', 25),
#   ('off.', 25),
#   ('look,', 25),
#   ('doing?', 25),
#   ('watch', 25),
#   ('kind', 25),
#   ('George)', 25),
#   ('thank', 25),
#   ('same', 25),
#   ('something.', 24),
#   ('its', 24),
#   ('gave', 24),
#   ('me?', 24),
#   ('does', 24),
#   ('bad', 24),
#   ('name', 24),
#   ('few', 24),
#   ('hear', 24),
#   ('what?', 24),
#   ('There', 24),
#   ('Listen,', 24),
#   ('nice', 24),
#   ("Let's", 24),
#   ('five', 23),
#   ('wanted', 23),
#   ('hot', 23),
#   ('away', 23),
#   ('do.', 23),
#   ('long', 23),
#   ('bring', 22),
#   ('couple', 22),
#   ('Its', 22),
#   ('try', 22),
#   ('New', 22),
#   ('this?', 22),
#   ('too.', 22),
#   ('happened', 22),
#   ('wait,', 22),
#   ('Mr.', 22),
#   ('wait', 22),
#   ('day', 22),
#   ('woman', 22),
#   ('later.', 22),
#   ("couldn't", 22),
#   ('left', 21),
#   ('When', 21),
#   ('coming', 21),
#   ('anything', 21),
#   ('hundred', 21),
#   ('Elaine)', 21),
#   ('Wait', 21),
#   ('things', 21),
#   ('hands', 21),
#   ('head', 21),
#   ('first', 21),
#   ("who's", 21),
#   ('found', 20),
#   ('man,', 20),
#   ('uh', 20),
#   ('car', 20),
#   ('Elaine.', 20),
#   ('hold', 20),
#   ('play', 20),
#   ('Uh', 20),
#   ('right?', 20),
#   ('sure', 20),
#   ('watching', 19),
#   ('trying', 19),
#   ('years', 19),
#   ('for?', 19),
#   ('man!', 19),
#   ('starts', 19),
#   ("you'll", 19),
#   ('work', 19),
#   ('again.', 19),
#   ('show', 19),
#   ('under', 19),
#   ('Jerry?', 19),
#   ('real', 19),
#   ('day.', 19),
#   ('turn', 19),
#   ('oh', 19),
#   ("Newman's", 19),
#   ('him,', 18),
#   ('behind', 18),
#   ('sorry.', 18),
#   ('pretty', 18),
#   ('to.', 18),
#   ('open', 18),
#   ('anything.', 18),
#   ('hand', 18),
#   ('Maybe', 18),
#   ('boy.', 18),
#   ('ask', 18),
#   ('meet', 18),
#   ('night.', 18),
#   ("'em.", 18),
#   ('huh.', 18),
#   ("haven't", 18),
#   ('sitting', 17),
#   ('Then', 17),
#   ('takes', 17),
#   ('eat', 17),
#   ('old', 17),
#   ('out,', 17),
#   ('Boy,', 17),
#   ('Get', 17),
#   ('supposed', 17),
#   ('up)', 17),
#   ('makes', 17),
#   ('wrong', 17),
#   ('listen', 17),
#   ('over.', 17),
#   ('Here', 17),
#   ('door', 16),
#   ('see,', 16),
#   ('telling', 16),
#   ('hey.', 16),
#   ('Ill', 16),
#   ('pay', 16),
#   ('walk', 16),
#   ('up!', 16),
#   ('across', 16),
#   ('Oh!', 16),
#   ("won't", 16),
#   ('them.', 16),
#   ('making', 16),
#   ('say?', 16),
#   ('Like', 16),
#   ('table', 16),
#   ('her,', 16),
#   ('back,', 16),
#   ('goes', 16),
#   ('remember', 16),
#   ('Why?', 16),
#   ('yes.', 16),
#   ('work.', 16),
#   ('See', 16),
#   ('ball', 16),
#   ('lost', 16),
#   ('look.', 16),
#   ('room', 16),
#   ('world', 16),
#   ("an'", 16),
#   ('down.', 16),
#   ('Thats', 15),
#   ('is.', 15),
#   ('business', 15),
#   ('game', 15),
#   ('money', 15),
#   ('taste', 15),
#   ('Let', 15),
#   ('sleep', 15),
#   ('someone', 15),
#   ('sit', 15),
#   ('care', 15),
#   ('go,', 15),
#   ('Where', 15),
#   ('there?', 15),
#   ('having', 15),
#   ('Wait,', 15),
#   ('Joe', 15),
#   ('piece', 15),
#   ('Right', 15),
#   ('Can', 15),
#   ('everything', 15),
#   ('must', 15),
#   ('without', 15),
#   ('life', 15),
#   ('might', 15),
#   ('set', 15),
#   ('Who', 15),
#   ('home', 15),
#   ('yeah!', 15),
#   ('stuff', 15),
#   ('able', 15),
#   ('Huh?', 15),
#   ('move', 15),
#   ('way,', 14),
#   ('phone)', 14),
#   ('Man,', 14),
#   ('okay.', 14),
#   ('youre', 14),
#   ('done', 14),
#   ('Okay.', 14),
#   ('throw', 14),
#   ('him)', 14),
#   ('ten', 14),
#   ('him?', 14),
#   ('happy', 14),
#   ('(He', 14),
#   ('good,', 14),
#   ('problem.', 14),
#   ('on?', 14),
#   ('ho', 14),
#   ('all.', 14),
#   ('movie', 14),
#   ('matter', 14),
#   ('knew', 14),
#   ('hard', 14),
#   ('idea', 14),
#   ('together.', 14),
#   ('face', 14),
#   ("wasn't", 14),
#   ('called', 14),
#   ('Of', 14),
#   ('that,', 14),
#   ('Little', 14),
#   ('Cosmo', 14),
#   ('Hi.', 13),
#   ('idea.', 13),
#   ('half', 13),
#   ('(makes', 13),
#   ('met', 13),
#   ('full', 13),
#   ('years.', 13),
#   ('ago.', 13),
#   ('between', 13),
#   ('turns', 13),
#   ('kill', 13),
#   ('already', 13),
#   ('live', 13),
#   ('cut', 13),
#   ('(Elaine', 13),
#   ('leaves)', 13),
#   ('cable', 13),
#   ('many', 13),
#   ('apartment)', 13),
#   ('somebody', 13),
#   ('used', 13),
#   ("isn't", 13),
#   ('before', 13),
#   ('started', 13),
#   ('Ok,', 13),
#   ('Yes!', 13),
#   ('on!', 13),
#   ('word', 13),
#   ('front', 13),
#   ('part', 13),
#   ('down,', 13),
#   ('drop', 13),
#   ('Really?', 13),
#   ("You've", 13),
#   ('air', 13),
#   ('Frank,', 13),
#   ('business.', 12),
#   ('again)', 12),
#   ('Take', 12),
#   ('friend.', 12),
#   ('shirt', 12),
#   ('her?', 12),
#   ('head.', 12),
#   ('Ya', 12),
#   ('one?', 12),
#   ('while', 12),
#   ('uh...', 12),
#   ('eating', 12),
#   ('yourself', 12),
#   ('money.', 12),
#   ('oh,', 12),
#   ('Newman.', 12),
#   ('night', 12),
#   ('Have', 12),
#   ('run', 12),
#   ('In', 12),
#   ("you'd", 12),
#   ('myself.', 12),
#   ('needs', 12),
#   ('ya.', 12),
#   ('pull', 12),
#   ("here's", 12),
#   ('bit', 12),
#   ('smell', 12),
#   ('see.', 12),
#   ('blood', 12),
#   ('Alright', 12),
#   ('running', 12),
#   ('bought', 12),
#   ('buy', 12),
#   ('apartment', 12),
#   ('talked', 12),
#   ('keys', 12),
#   ('(looking', 12),
#   ('playing', 12),
#   ('golf', 12),
#   ('Aw,', 12),
#   ("d'you", 12),
#   ('heard', 12),
#   ('book', 12),
#   ('Newman,', 12),
#   ('gets', 11),
#   ('door.', 11),
#   ('guy,', 11),
#   ('Cause', 11),
#   ('best', 11),
#   ('apartment.', 11),
#   ('baby.', 11),
#   ('sorry', 11),
#   ('"', 11),
#   ('waiting', 11),
#   ('life.', 11),
#   ('boy,', 11),
#   ('hands)', 11),
#   ('His', 11),
#   ('ya,', 11),
#   ('Listen', 11),
#   ('each', 11),
#   ('ah', 11),
#   ('place.', 11),
#   ('go?', 11),
#   ('George!', 11),
#   ('giving', 11),
#   ('Anyway,', 11),
#   ('head)', 11),
#   ('tape', 11),
#   ("We'll", 11),
#   ('stand', 11),
#   ('street', 11),
#   ('hours', 11),
#   ('probably', 11),
#   ('Um,', 11),
#   ('alright,', 11),
#   ('alright.', 11),
#   ('walking', 11),
#   ('being', 11),
#   ('walks', 11),
#   ('quite', 11),
#   ('course', 11),
#   ('water', 11),
#   ('Serenity', 11),
#   ('To', 10),
#   ('borrow', 10),
#   ('not?', 10),
#   ('pizza', 10),
#   ('people,', 10),
#   ('One', 10),
#   ('(looks', 10),
#   ('going?', 10),
#   ('bunch', 10),
#   ('time,', 10),
#   ('wrong.', 10),
#   ('four', 10),
#   ('puts', 10),
#   ('minutes.', 10),
#   ('guy.', 10),
#   ('outta', 10),
#   ('side', 10),
#   ('way.', 10),
#   ('lets', 10),
#   ('window)', 10),
#   ('sex', 10),
#   ('yeah?', 10),
#   ('tried', 10),
#   ('Remember', 10),
#   ('paper', 10),
#   ('away.', 10),
#   ('looked', 10),
#   ('(quietly)', 10),
#   ('worry', 10),
#   ('see?', 10),
#   ('happens', 10),
#   ('car.', 10),
#   ('once', 10),
#   ('fat', 10),
#   ('grab', 10),
#   ('bag', 10),
#   ('since', 10),
#   ('it)', 10),
#   ('pair', 10),
#   ('holding', 10),
#   ('huh,', 10),
#   ('free', 10),
#   ('about.', 10),
#   ('hey!', 10),
#   ('drive', 10),
#   ('hate', 10),
#   ('driving', 10),
#   ('clean', 10),
#   ('Good', 10),
#   ('towards', 10),
#   ('ran', 10),
#   ('almost', 10),
#   ('Miss', 10),
#   ('yes,', 10),
#   ('sound', 10),
#   ('(Looks', 10),
#   ('wearing', 10),
#   ('Mickey', 10),
#   ('store.', 10),
#   ('Here,', 10),
#   ('again,', 10),
#   ('buddy', 10),
#   ('will.', 10),
#   ('stick', 10),
#   ('fun', 10),
#   ('cause', 9),
#   ('sorry,', 9),
#   ('stuff.', 9),
#   ('Hes', 9),
#   ('now!', 9),
#   ('rock', 9),
#   ('mind', 9),
#   ('is,', 9),
#   ('Whoa,', 9),
#   ('different', 9),
#   ('end', 9),
#   ('job.', 9),
#   ('jacket', 9),
#   ('asked', 9),
#   ('points', 9),
#   ('percent', 9),
#   ('pants', 9),
#   ('Or', 9),
#   ('crazy.', 9),
#   ('about?', 9),
#   ('building.', 9),
#   ('(Starts', 9),
#   ('start', 9),
#   ('onto', 9),
#   ('out!', 9),
#   ('Bob', 9),
#   ('..', 9),
#   ('Got', 9),
#   ('exits)', 9),
#   ('birthday', 9),
#   ('today?', 9),
#   ('For', 9),
#   ('putting', 9),
#   ('leave)', 9),
#   ('threw', 9),
#   ('dog', 9),
#   ('forgot', 9),
#   ("Where's", 9),
#   ('leaves', 9),
#   ('Elaine!', 9),
#   ('George?', 9),
#   ('am.', 9),
#   ('leave', 9),
#   ('(George', 9),
#   ('bathroom', 9),
#   ('Okay', 9),
#   ('yes', 9),
#   ('arm', 9),
#   ('working', 9),
#   ('catch', 9),
#   ('did.', 9),
#   ('stay', 9),
#   ('going.', 9),
#   ('Yes.', 9),
#   ('wish', 9),
#   ('so.', 9),
#   ('(grabs', 9),
#   ('Alright.', 9),
#   ('thinks', 9),
#   ('kept', 9),
#   ("goin'", 9),
#   ('worked', 9),
#   ('pocket)', 9),
#   ('Cubans.', 9),
#   ('in,', 9),
#   ('much.', 9),
#   ('Ooh,', 9),
#   ('up?', 9),
#   ('Your', 9),
#   ('[In', 9),
#   ('ear]', 9),
#   ('myself', 9),
#   ('face.', 9),
#   ('enough', 9),
#   ('nothing.', 9),
#   ('down)', 9),
#   ('killing', 9),
#   ('everybody', 9),
#   ('(points', 9),
#   ('food', 9),
#   ('handle', 8),
#   ('back!', 8),
#   ('Hi,', 8),
#   ('phone.', 8),
#   ('guys.', 8),
#   ('happen.', 8),
#   ('day,', 8),
#   ('hi', 8),
#   ('game.', 8),
#   ('off,', 8),
#   ('friends', 8),
#   ('Wow.', 8),
#   ('liked', 8),
#   ('Youre', 8),
#   ('bet', 8),
#   ('dinner', 8),
#   ('decided', 8),
#   ('done.', 8),
#   ('bathroom.', 8),
#   ('anymore.', 8),
#   ('guy?', 8),
#   ('that!', 8),
#   ('think?', 8),
#   ('problem', 8),
#   ('No!', 8),
#   ('do,', 8),
#   ('mind.', 8),
#   ('Go', 8),
#   ('reading', 8),
#   ('double', 8),
#   ('shut', 8),
#   ('food.', 8),
#   ('From', 8),
#   ('broke', 8),
#   ('deal.', 8),
#   ('home.', 8),
#   ('year', 8),
#   ('(turns', 8),
#   ('until', 8),
#   ('cost', 8),
#   ('house', 8),
#   ('women', 8),
#   ('what,', 8),
#   ("C'mon", 8),
#   ('(', 8),
#   ('picture', 8),
#   ("doin'", 8),
#   ('ready', 8),
#   ('owe', 8),
#   ('blew', 8),
#   ('Yes', 8),
#   ('Ohh,', 8),
#   ('top', 8),
#   ('works', 8),
#   ('mention', 8),
#   ('runs', 8),
#   ('close', 8),
#   ('beach.', 8),
#   ('Newman!', 8),
#   ('foot', 8),
#   ('Right.', 8),
#   ('call.', 8),
#   ('number', 8),
#   ('Hello.', 8),
#   ('person', 8),
#   ('date', 8),
#   ('As', 8),
#   ('clothes', 8),
#   ('thing,', 8),
#   ('park', 8),
#   ('sold', 8),
#   ('then,', 8),
#   ('during', 8),
#   ('(takes', 8),
#   ('cold', 8),
#   ('starting', 8),
#   ('uh?', 8),
#   ('upset', 8),
#   ('Mrs.', 8),
#   ('Hi', 8),
#   ('hello', 8),
#   ('calling', 8),
#   ("You'll", 8),
#   ('TV', 8),
#   ('ticket', 8),
#   ('inside', 8),
#   ('Yeah..', 8),
#   ('throws', 8),
#   ('Mickey,', 8),
#   ("C'mon,", 8),
#   ('thinking', 8),
#   ('are.', 8),
#   ('case', 8),
#   ('store', 8),
#   ('shirt.', 8),
#   ('out)', 8),
#   ("aren't", 8),
#   ('voice', 8),
#   ('read', 8),
#   ('sits', 8),
#   ('back)', 8),
#   ('kids', 8),
#   ('away)', 8),
#   ('Frank', 8),
#   ('important', 8),
#   ('meat', 8),
#   ('Mr', 8),
#   ('buddy,', 7),
#   ('hes', 7),
#   ('strange.', 7),
#   ('number.', 7),
#   ('air.', 7),
#   ('week.', 7),
#   ('rid', 7),
#   ('sound)', 7),
#   ('know?', 7),
#   ('understand', 7),
#   ('people.', 7),
#   ('Why,', 7),
#   ('Woah,', 7),
#   ('now?', 7),
#   ('problem?', 7),
#   ('thousand', 7),
#   ('dollars.', 7),
#   ('dollars', 7),
#   ('didnt', 7),
#   ('Lets', 7),
#   ('(from', 7),
#   ('trouble', 7),
#   ('Any', 7),
#   ('second', 7),
#   ('Where?', 7),
#   ('thing.', 7),
#   ('body', 7),
#   ('yeah...', 7),
#   ('glad', 7),
#   ('house.', 7),
#   ('rubs', 7),
#   ('break', 7),
#   ('shoulder)', 7),
#   ('Oh?', 7),
#   ('likes', 7),
#   ('And,', 7),
#   ('table,', 7),
#   ('table)', 7),
#   ('fine.', 7),
#   ('high', 7),
#   ('accident.', 7),
#   ('table.', 7),
#   ('hurt', 7),
#   ('great.', 7),
#   ('card.', 7),
#   ('was.', 7),
#   ('boy', 7),
#   ('happened?', 7),
#   ('bottle', 7),
#   ("It'll", 7),
#   ('knows', 7),
#   ('Elaine?', 7),
#   ('mail', 7),
#   ('them)', 7),
#   ('think,', 7),
#   ('order', 7),
#   ('so,', 7),
#   ('mean?', 7),
#   ('(putting', 7),
#   ('fine', 7),
#   ('seat', 7),
#   ...]}

# %% [markdown]
# __A7.__ _(5 points)_ Load the `data/stop-words.txt` file into a list. Find the 10 most common words for each of the main characters that are not in this list of stop words. Put these most common words in a dictionary data strucutre.

# %%
with open('data/stop-words.txt') as reader:
    stopWords = reader.read()

stopWordsList = stopWords.split('\n')
mostCommonWords = {'JERRY': [], 'GEORGE': [], 'ELAINE': [], 'KRAMER': []}
for character in mainCharacters.keys():
    for word in wordCounter[character]:
        if word[0] not in stopWordsList and len(mostCommonWords[character]) < 10:
            mostCommonWords[character].append(word[0])
mostCommonWords
# Out:
# {'JERRY': ['I',
#   'You',
#   "I'm",
#   'What',
#   'like',
#   'know',
#   'get',
#   'Oh,',
#   'Well,',
#   'it.'],
#  'GEORGE': ['I',
#   'You',
#   "I'm",
#   'like',
#   'What',
#   'know',
#   'get',
#   "It's",
#   'think',
#   'got'],
#  'ELAINE': ['I',
#   'You',
#   "I'm",
#   'Oh,',
#   'What',
#   'know',
#   'Well,',
#   'like',
#   'get',
#   'got'],
#  'KRAMER': ['I',
#   "I'm",
#   'You',
#   'Well,',
#   'Yeah,',
#   'Oh,',
#   'got',
#   'get',
#   'know',
#   'like']}
